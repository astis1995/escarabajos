# %% [markdown]
# ## Author: Vinicio Soto, CICIMA
# ### This script calculates absortptance, reflectance and transmittance if you provide both reflectance and transflectance data, works with .txt files
# ### Files should be jump corrected and averaged

# %%
#Dependencies

import pandas as pd
import numpy as np
import matplotlib
import os
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import itertools

# %%
#constants
markersize = 2

# %% [markdown]
# ### Data paths

# %%
#report path
report_location = r"E:\CICIMA\OneDrive_2024-03-14\Estudio Optico Escarabajos\report"

#absorptance and reflectance save path
save_path = r"E:\CICIMA\OneDrive_2024-03-14\Estudio Optico Escarabajos\clean_data"

#code name samples path
code_name_path = r"E:\CICIMA\OneDrive_2024-03-14\Estudio Optico Escarabajos\CODE NAME SAMPLES.txt"

#patterns and samples

#transflectance averages
transflectance_data_path = r"E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average"
transmittance_data_path = r"E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average"

# %%
### Create folder if not exists

# %%
def create_folder_if_not_exists(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder '{folder_path}' created successfully.")
    else:
        print(f"Folder '{folder_path}' already exists.")
        
def filter_substring_elements(path_strings, substring):
    filtered_paths = [path for path in path_strings if substring in path]
    return filtered_paths

# %%
### List files in folder

# %%
import os


def list_files_in_folder(folder_path):
    files_only_in_folder = []
    
    # Get the list of all files in the folder and its subfolders
    all_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            all_files.append(os.path.join(root, file))
    
    # Get the list of files that are only in the top-level folder
    for file in all_files:
        if os.path.isfile(file) and os.path.dirname(file) == folder_path:
            files_only_in_folder.append(file)
    
    return files_only_in_folder

transflectance_file_list_general = list_files_in_folder(transflectance_data_path)
transmittance_file_list_general = list_files_in_folder(transmittance_data_path)
#std_dev_file_list
#transmittance_file_list_general

# %% [markdown]
# ### Dataframe List

# %%
transmittance_dataframes = []
absorptance_dataframes = []
reflectance_dataframes = []
transflectance_dataframes = []

# %% [markdown]
# ### Absorptance

# %%
#read codes
codes_df = pd.read_csv(code_name_path, sep="	",header=0,  
                     names=["code", "description"]) 
codes_df
# Out:
#               code                             description
# 0      C.KALI.LA22       CHRYSINA KALININI LA AMISTAD 2022
# 1      C.RESP.MV23                 C. RESPLENDENS MV 23-19
# 2      C.CUPR.MV23             C. CUPREOMARGINATA MV 23-15
# 3      C.AURI.INBI           C. AURIGANS INBIO DESCABEZADO
# 4      C.CHRY.6713       C. CHRYSARGYREA INBIOCRI002426713
# 5      C.OPTI.8.17          C. OPTIMA #81 7 SIGNO PREGUNTA
# 6      C.CHRY.MV73                C. CHRYSARGYREA #73 MV23
# 7      C.CHRY.MV84                C. CHRYSARGYREA #84 MV23
# 8      S.BELT.1063         STRIGIDIA BELTI INBIO0004211063
# 9      S.GLAB.0620     STRIGIDIA GLABRA INBIOCRI0003420620
# 10     S.SIGN.PREG                STRIGIDIA SIGNO PREGUNTA
# 11         NI#0002                                   NI #2
# 12     P.GRAT.3610                PTENOMELA GRATIOSA 03610
# 13    MACRASPIS.SP                MACRASPIS SIGNO PREGUNTA
# 14         NI#0001                                 NI #001
# 15     M.HIRT.DIUR            MACRASPIS HIRTIVENTIS DIURNA
# 16     C.BOUC.CO23  CHRYSINA BOUCARDI CORONADO 2(ICP) 2023
# 17       PELID.001                                 PELID 1
# 18       PLATY.001                                 PLATY 1
# 19       PELID.002                                 PELID 2
# 20  C.BOUC.INB5610         C.BOUCARDI_INB0004065610_MORADO
# 21  C.BOUC.INB5423           C.BOUCARDI_INB0040G5423_COBRE

# %%
#print(file)

# %% [markdown]
# ### Reflectance

# %%
for code in codes_df["code"]:
    transflectance_file_list_filtered = filter_substring_elements(transflectance_file_list_general, code)
    transmittance_file_list_filtered = filter_substring_elements(transmittance_file_list_general, code)
    #print("len")
    #print(len(transflectance_file_list_filtered))
    #print(len(transmittance_file_list_filtered))
    for file1 in transflectance_file_list_filtered:
        for file2 in transmittance_file_list_filtered:
                
                print(file1)
                print(file2)
                print("*****")
                transflectance_df = pd.read_csv(file1, sep="	",header=None, names=["wavelength", "transflectance"]).dropna()
                transflectance_df = transflectance_df[transflectance_df['wavelength'] <= 2000]
                transflectance_df.loc[transflectance_df['transflectance'] > 100, 'transflectance'] = 100
                transflectance_dataframes.append(transflectance_df)
                transflectance_df["code"] = code
                transmittance_df  = pd.read_csv(file2, sep="	",header=None, names=["wavelength", "transmittance"]).dropna()
                transmittance_df = transmittance_df[transmittance_df['wavelength'] <= 2000]
                transmittance_df.loc[transmittance_df['transmittance'] > 100, 'transmittance'] = 100
                transmittance_df["code"] = code
                transmittance_dataframes.append(transmittance_df)
                
                
                #print(transflectance_df)
                #print(transmittance_df)
                # Merge the two DataFrames on 'Wavelength' column
                merged_df = pd.merge(transflectance_df, transmittance_df, on='wavelength')
                
                #print("merged")
                #print(merged_df)
                # Subtract 'transmittance' from 'Transflectance' and create a new column 'Subtracted_Value'
                merged_df['reflectance'] = merged_df['transflectance'] - merged_df['transmittance']
                
                
                #Calculate absorptance
                absorptance_df = pd.DataFrame([])
                absorptance_df["wavelength"] = transflectance_df["wavelength"]
                absorptance_df["absorptance"] = 100 - transflectance_df["transflectance"]
                absorptance_df["code"] = code
                absorptance_dataframes.append(absorptance_df)
                #print("absorptance")
                #print(absorptance_df)
                
                # Create a new DataFrame with 'Wavelength' and 'Subtracted_Value' columns
                reflectance_df = merged_df[['wavelength', 'reflectance']]
                reflectance_df.file = file1
                reflectance_df.code = code
                reflectance_df["code"] = code
                print("reflectance.file")
                print(reflectance_df.file)
                reflectance_dataframes.append(reflectance_df)
                
                
                reflectance_df.plot(x='wavelength', y='reflectance', kind='scatter', s=markersize, title = code + " mean and moving avg", figsize = (8, 6))
                #plt.show()
                #print(reflectance_df)
                
                #saves files
                
                #reflectance 
                
                corrected_path = save_path +"\\" + "reflectance\\"

                if not os.path.exists(corrected_path):
                    os.mkdir(corrected_path)

                new_filename = code +"-RX.txt"
                reflectance_numpy = reflectance_df.to_numpy()
                new_archive_name = corrected_path + new_filename
                np.savetxt(new_archive_name, reflectance_numpy,fmt='%s', delimiter="\t")
                
                #transmittance 
                
                corrected_path = save_path +"\\" + "transmittance\\"

                if not os.path.exists(corrected_path):
                    os.mkdir(corrected_path)

                new_filename = code +"-TX.txt"
                transmittance_numpy = transmittance_df.to_numpy()
                new_archive_name = corrected_path + new_filename
                np.savetxt(new_archive_name, transmittance_numpy,fmt='%s', delimiter="\t")
                
                #absorptance 
                
                corrected_path = save_path +"\\" + "absorptance\\"

                if not os.path.exists(corrected_path):
                    os.mkdir(corrected_path)

                new_filename = code +"-AX.txt"
                absorptance_numpy = absorptance_df.to_numpy()
                new_archive_name = corrected_path + new_filename
                np.savetxt(new_archive_name, absorptance_numpy,fmt='%s', delimiter="\t")
                
                #transflectance 
                
                corrected_path = save_path +"\\" + "transflectance\\"

                if not os.path.exists(corrected_path):
                    os.mkdir(corrected_path)

                new_filename = code +"-TXRX.txt"
                transflectance_numpy = transflectance_df.to_numpy()
                new_archive_name = corrected_path + new_filename
                np.savetxt(new_archive_name, transflectance_numpy,fmt='%s', delimiter="\t")
                
                
                
                print(transflectance_df)
                print(transmittance_df)
                print(reflectance_df)
                print(absorptance_df)
# Out:
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.KALI.LA22_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.KALI.LA22_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.KALI.LA22_AVERAGE.txt
#       wavelength  transflectance         code
# 5          255.0        5.753851  C.KALI.LA22
# 6          256.0        5.721774  C.KALI.LA22
# 7          257.0        5.695559  C.KALI.LA22
# 8          258.0        5.676867  C.KALI.LA22
# 9          259.0        5.658812  C.KALI.LA22
# ...          ...             ...          ...
# 1746      1996.0       73.548358  C.KALI.LA22
# 1747      1997.0       73.940907  C.KALI.LA22
# 1748      1998.0       74.335014  C.KALI.LA22
# 1749      1999.0       74.443687  C.KALI.LA22
# 1750      2000.0       74.670560  C.KALI.LA22
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       6.758361  C.KALI.LA22
# 6          256.0       6.539275  C.KALI.LA22
# 7          257.0       6.351019  C.KALI.LA22
# 8          258.0       6.159842  C.KALI.LA22
# 9          259.0       5.977477  C.KALI.LA22
# ...          ...            ...          ...
# 1746      1996.0      54.831801  C.KALI.LA22
# 1747      1997.0      54.956323  C.KALI.LA22
# 1748      1998.0      55.001484  C.KALI.LA22
# 1749      1999.0      55.059317  C.KALI.LA22
# 1750      2000.0      55.069254  C.KALI.LA22
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0    -1.004509  C.KALI.LA22
# 1          256.0    -0.817501  C.KALI.LA22
# 2          257.0    -0.655459  C.KALI.LA22
# 3          258.0    -0.482975  C.KALI.LA22
# 4          259.0    -0.318666  C.KALI.LA22
# ...          ...          ...          ...
# 1741      1996.0    18.716557  C.KALI.LA22
# 1742      1997.0    18.984584  C.KALI.LA22
# 1743      1998.0    19.333531  C.KALI.LA22
# 1744      1999.0    19.384369  C.KALI.LA22
# 1745      2000.0    19.601306  C.KALI.LA22
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    94.246149  C.KALI.LA22
# 6          256.0    94.278226  C.KALI.LA22
# 7          257.0    94.304441  C.KALI.LA22
# 8          258.0    94.323133  C.KALI.LA22
# 9          259.0    94.341188  C.KALI.LA22
# ...          ...          ...          ...
# 1746      1996.0    26.451642  C.KALI.LA22
# 1747      1997.0    26.059093  C.KALI.LA22
# 1748      1998.0    25.664986  C.KALI.LA22
# 1749      1999.0    25.556313  C.KALI.LA22
# 1750      2000.0    25.329440  C.KALI.LA22
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.RESP.MV23_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.RESP.MV23_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.RESP.MV23_AVERAGE.txt
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
#       wavelength  transflectance         code
# 5          255.0        7.222642  C.RESP.MV23
# 6          256.0        7.195912  C.RESP.MV23
# 7          257.0        7.163831  C.RESP.MV23
# 8          258.0        7.136356  C.RESP.MV23
# 9          259.0        7.124970  C.RESP.MV23
# ...          ...             ...          ...
# 1746      1996.0       72.804432  C.RESP.MV23
# 1747      1997.0       73.221347  C.RESP.MV23
# 1748      1998.0       73.512256  C.RESP.MV23
# 1749      1999.0       73.617781  C.RESP.MV23
# 1750      2000.0       73.778444  C.RESP.MV23
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.308572  C.RESP.MV23
# 6          256.0       0.304674  C.RESP.MV23
# 7          257.0       0.306025  C.RESP.MV23
# 8          258.0       0.303239  C.RESP.MV23
# 9          259.0       0.305173  C.RESP.MV23
# ...          ...            ...          ...
# 1746      1996.0      57.242513  C.RESP.MV23
# 1747      1997.0      57.295204  C.RESP.MV23
# 1748      1998.0      57.417417  C.RESP.MV23
# 1749      1999.0      57.421502  C.RESP.MV23
# 1750      2000.0      57.424571  C.RESP.MV23
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     6.914069  C.RESP.MV23
# 1          256.0     6.891238  C.RESP.MV23
# 2          257.0     6.857806  C.RESP.MV23
# 3          258.0     6.833117  C.RESP.MV23
# 4          259.0     6.819798  C.RESP.MV23
# ...          ...          ...          ...
# 1741      1996.0    15.561919  C.RESP.MV23
# 1742      1997.0    15.926143  C.RESP.MV23
# 1743      1998.0    16.094839  C.RESP.MV23
# 1744      1999.0    16.196279  C.RESP.MV23
# 1745      2000.0    16.353874  C.RESP.MV23
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    92.777358  C.RESP.MV23
# 6          256.0    92.804088  C.RESP.MV23
# 7          257.0    92.836169  C.RESP.MV23
# 8          258.0    92.863644  C.RESP.MV23
# 9          259.0    92.875030  C.RESP.MV23
# ...          ...          ...          ...
# 1746      1996.0    27.195568  C.RESP.MV23
# 1747      1997.0    26.778653  C.RESP.MV23
# 1748      1998.0    26.487744  C.RESP.MV23
# 1749      1999.0    26.382219  C.RESP.MV23
# 1750      2000.0    26.221556  C.RESP.MV23
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.CUPR.MV23_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.CUPR.MV23_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.CUPR.MV23_AVERAGE.txt
#       wavelength  transflectance         code
# 5          255.0        6.735634  C.CUPR.MV23
# 6          256.0        6.701637  C.CUPR.MV23
# 7          257.0        6.672500  C.CUPR.MV23
# 8          258.0        6.649442  C.CUPR.MV23
# 9          259.0        6.617581  C.CUPR.MV23
# ...          ...             ...          ...
# 1746      1996.0       79.853413  C.CUPR.MV23
# 1747      1997.0       80.044257  C.CUPR.MV23
# 1748      1998.0       80.377044  C.CUPR.MV23
# 1749      1999.0       80.245013  C.CUPR.MV23
# 1750      2000.0       80.373801  C.CUPR.MV23
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.344349  C.CUPR.MV23
# 6          256.0       0.342364  C.CUPR.MV23
# 7          257.0       0.339407  C.CUPR.MV23
# 8          258.0       0.338753  C.CUPR.MV23
# 9          259.0       0.337748  C.CUPR.MV23
# ...          ...            ...          ...
# 1746      1996.0      70.298774  C.CUPR.MV23
# 1747      1997.0      70.364298  C.CUPR.MV23
# 1748      1998.0      70.526217  C.CUPR.MV23
# 1749      1999.0      70.490679  C.CUPR.MV23
# 1750      2000.0      70.494854  C.CUPR.MV23
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     6.391286  C.CUPR.MV23
# 1          256.0     6.359274  C.CUPR.MV23
# 2          257.0     6.333093  C.CUPR.MV23
# 3          258.0     6.310689  C.CUPR.MV23
# 4          259.0     6.279834  C.CUPR.MV23
# ...          ...          ...          ...
# 1741      1996.0     9.554639  C.CUPR.MV23
# 1742      1997.0     9.679958  C.CUPR.MV23
# 1743      1998.0     9.850827  C.CUPR.MV23
# 1744      1999.0     9.754334  C.CUPR.MV23
# 1745      2000.0     9.878947  C.CUPR.MV23
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    93.264366  C.CUPR.MV23
# 6          256.0    93.298363  C.CUPR.MV23
# 7          257.0    93.327500  C.CUPR.MV23
# 8          258.0    93.350558  C.CUPR.MV23
# 9          259.0    93.382419  C.CUPR.MV23
# ...          ...          ...          ...
# 1746      1996.0    20.146587  C.CUPR.MV23
# 1747      1997.0    19.955743  C.CUPR.MV23
# 1748      1998.0    19.622956  C.CUPR.MV23
# 1749      1999.0    19.754987  C.CUPR.MV23
# 1750      2000.0    19.626199  C.CUPR.MV23
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.AURI.INBI_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.AURI.INBI_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.AURI.INBI_AVERAGE.txt
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
#       wavelength  transflectance         code
# 5          255.0        6.242102  C.AURI.INBI
# 6          256.0        6.218145  C.AURI.INBI
# 7          257.0        6.200173  C.AURI.INBI
# 8          258.0        6.170842  C.AURI.INBI
# 9          259.0        6.141817  C.AURI.INBI
# ...          ...             ...          ...
# 1746      1996.0       70.384197  C.AURI.INBI
# 1747      1997.0       70.578498  C.AURI.INBI
# 1748      1998.0       70.936745  C.AURI.INBI
# 1749      1999.0       71.135491  C.AURI.INBI
# 1750      2000.0       71.297660  C.AURI.INBI
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.336480  C.AURI.INBI
# 6          256.0       0.331562  C.AURI.INBI
# 7          257.0       0.330087  C.AURI.INBI
# 8          258.0       0.331627  C.AURI.INBI
# 9          259.0       0.331079  C.AURI.INBI
# ...          ...            ...          ...
# 1746      1996.0      55.608428  C.AURI.INBI
# 1747      1997.0      55.656792  C.AURI.INBI
# 1748      1998.0      55.691217  C.AURI.INBI
# 1749      1999.0      55.679737  C.AURI.INBI
# 1750      2000.0      55.764685  C.AURI.INBI
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     5.905622  C.AURI.INBI
# 1          256.0     5.886583  C.AURI.INBI
# 2          257.0     5.870086  C.AURI.INBI
# 3          258.0     5.839215  C.AURI.INBI
# 4          259.0     5.810737  C.AURI.INBI
# ...          ...          ...          ...
# 1741      1996.0    14.775769  C.AURI.INBI
# 1742      1997.0    14.921706  C.AURI.INBI
# 1743      1998.0    15.245528  C.AURI.INBI
# 1744      1999.0    15.455754  C.AURI.INBI
# 1745      2000.0    15.532976  C.AURI.INBI
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    93.757898  C.AURI.INBI
# 6          256.0    93.781855  C.AURI.INBI
# 7          257.0    93.799827  C.AURI.INBI
# 8          258.0    93.829158  C.AURI.INBI
# 9          259.0    93.858183  C.AURI.INBI
# ...          ...          ...          ...
# 1746      1996.0    29.615803  C.AURI.INBI
# 1747      1997.0    29.421502  C.AURI.INBI
# 1748      1998.0    29.063255  C.AURI.INBI
# 1749      1999.0    28.864509  C.AURI.INBI
# 1750      2000.0    28.702340  C.AURI.INBI
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.CHRY.6713_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.CHRY.6713_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.CHRY.6713_AVERAGE.txt
#       wavelength  transflectance         code
# 5          255.0        6.060476  C.CHRY.6713
# 6          256.0        6.038712  C.CHRY.6713
# 7          257.0        6.016479  C.CHRY.6713
# 8          258.0        5.992391  C.CHRY.6713
# 9          259.0        5.954435  C.CHRY.6713
# ...          ...             ...          ...
# 1746      1996.0       66.853082  C.CHRY.6713
# 1747      1997.0       66.940693  C.CHRY.6713
# 1748      1998.0       67.177444  C.CHRY.6713
# 1749      1999.0       67.193573  C.CHRY.6713
# 1750      2000.0       67.120558  C.CHRY.6713
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.261577  C.CHRY.6713
# 6          256.0       0.260461  C.CHRY.6713
# 7          257.0       0.260374  C.CHRY.6713
# 8          258.0       0.258340  C.CHRY.6713
# 9          259.0       0.257794  C.CHRY.6713
# ...          ...            ...          ...
# 1746      1996.0      42.232424  C.CHRY.6713
# 1747      1997.0      42.249750  C.CHRY.6713
# 1748      1998.0      42.336483  C.CHRY.6713
# 1749      1999.0      42.324085  C.CHRY.6713
# 1750      2000.0      42.231947  C.CHRY.6713
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     5.798898  C.CHRY.6713
# 1          256.0     5.778250  C.CHRY.6713
# 2          257.0     5.756104  C.CHRY.6713
# 3          258.0     5.734052  C.CHRY.6713
# 4          259.0     5.696641  C.CHRY.6713
# ...          ...          ...          ...
# 1741      1996.0    24.620658  C.CHRY.6713
# 1742      1997.0    24.690944  C.CHRY.6713
# 1743      1998.0    24.840961  C.CHRY.6713
# 1744      1999.0    24.869488  C.CHRY.6713
# 1745      2000.0    24.888611  C.CHRY.6713
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    93.939524  C.CHRY.6713
# 6          256.0    93.961288  C.CHRY.6713
# 7          257.0    93.983521  C.CHRY.6713
# 8          258.0    94.007609  C.CHRY.6713
# 9          259.0    94.045565  C.CHRY.6713
# ...          ...          ...          ...
# 1746      1996.0    33.146918  C.CHRY.6713
# 1747      1997.0    33.059307  C.CHRY.6713
# 1748      1998.0    32.822556  C.CHRY.6713
# 1749      1999.0    32.806427  C.CHRY.6713
# 1750      2000.0    32.879442  C.CHRY.6713
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.OPTI.8.17_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.OPTI.8.17_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.OPTI.8.17_AVERAGE.txt
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
#       wavelength  transflectance         code
# 5          255.0        6.079938  C.OPTI.8.17
# 6          256.0        6.050235  C.OPTI.8.17
# 7          257.0        6.026278  C.OPTI.8.17
# 8          258.0        6.011217  C.OPTI.8.17
# 9          259.0        5.988604  C.OPTI.8.17
# ...          ...             ...          ...
# 1746      1996.0       65.896678  C.OPTI.8.17
# 1747      1997.0       66.018081  C.OPTI.8.17
# 1748      1998.0       66.188886  C.OPTI.8.17
# 1749      1999.0       66.313599  C.OPTI.8.17
# 1750      2000.0       66.429952  C.OPTI.8.17
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.195685  C.OPTI.8.17
# 6          256.0       0.192208  C.OPTI.8.17
# 7          257.0       0.190868  C.OPTI.8.17
# 8          258.0       0.189763  C.OPTI.8.17
# 9          259.0       0.190044  C.OPTI.8.17
# ...          ...            ...          ...
# 1746      1996.0      35.468323  C.OPTI.8.17
# 1747      1997.0      35.396918  C.OPTI.8.17
# 1748      1998.0      35.511248  C.OPTI.8.17
# 1749      1999.0      35.547180  C.OPTI.8.17
# 1750      2000.0      35.421991  C.OPTI.8.17
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     5.884253  C.OPTI.8.17
# 1          256.0     5.858027  C.OPTI.8.17
# 2          257.0     5.835409  C.OPTI.8.17
# 3          258.0     5.821454  C.OPTI.8.17
# 4          259.0     5.798560  C.OPTI.8.17
# ...          ...          ...          ...
# 1741      1996.0    30.428355  C.OPTI.8.17
# 1742      1997.0    30.621162  C.OPTI.8.17
# 1743      1998.0    30.677637  C.OPTI.8.17
# 1744      1999.0    30.766419  C.OPTI.8.17
# 1745      2000.0    31.007961  C.OPTI.8.17
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    93.920062  C.OPTI.8.17
# 6          256.0    93.949765  C.OPTI.8.17
# 7          257.0    93.973722  C.OPTI.8.17
# 8          258.0    93.988783  C.OPTI.8.17
# 9          259.0    94.011396  C.OPTI.8.17
# ...          ...          ...          ...
# 1746      1996.0    34.103322  C.OPTI.8.17
# 1747      1997.0    33.981919  C.OPTI.8.17
# 1748      1998.0    33.811114  C.OPTI.8.17
# 1749      1999.0    33.686401  C.OPTI.8.17
# 1750      2000.0    33.570048  C.OPTI.8.17
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.CHRY.MV73_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.CHRY.MV73_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.CHRY.MV73_AVERAGE.txt
#       wavelength  transflectance         code
# 5          255.0        6.403194  C.CHRY.MV73
# 6          256.0        6.386155  C.CHRY.MV73
# 7          257.0        6.360120  C.CHRY.MV73
# 8          258.0        6.338724  C.CHRY.MV73
# 9          259.0        6.305029  C.CHRY.MV73
# ...          ...             ...          ...
# 1746      1996.0       75.609942  C.CHRY.MV73
# 1747      1997.0       75.754957  C.CHRY.MV73
# 1748      1998.0       76.146678  C.CHRY.MV73
# 1749      1999.0       76.129951  C.CHRY.MV73
# 1750      2000.0       76.353069  C.CHRY.MV73
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.209642  C.CHRY.MV73
# 6          256.0       0.208303  C.CHRY.MV73
# 7          257.0       0.207623  C.CHRY.MV73
# 8          258.0       0.209401  C.CHRY.MV73
# 9          259.0       0.209337  C.CHRY.MV73
# ...          ...            ...          ...
# 1746      1996.0      54.200970  C.CHRY.MV73
# 1747      1997.0      54.320252  C.CHRY.MV73
# 1748      1998.0      54.422676  C.CHRY.MV73
# 1749      1999.0      54.454078  C.CHRY.MV73
# 1750      2000.0      54.524880  C.CHRY.MV73
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     6.193551  C.CHRY.MV73
# 1          256.0     6.177852  C.CHRY.MV73
# 2          257.0     6.152497  C.CHRY.MV73
# 3          258.0     6.129322  C.CHRY.MV73
# 4          259.0     6.095693  C.CHRY.MV73
# ...          ...          ...          ...
# 1741      1996.0    21.408971  C.CHRY.MV73
# 1742      1997.0    21.434705  C.CHRY.MV73
# 1743      1998.0    21.724003  C.CHRY.MV73
# 1744      1999.0    21.675873  C.CHRY.MV73
# 1745      2000.0    21.828189  C.CHRY.MV73
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    93.596806  C.CHRY.MV73
# 6          256.0    93.613845  C.CHRY.MV73
# 7          257.0    93.639880  C.CHRY.MV73
# 8          258.0    93.661276  C.CHRY.MV73
# 9          259.0    93.694971  C.CHRY.MV73
# ...          ...          ...          ...
# 1746      1996.0    24.390058  C.CHRY.MV73
# 1747      1997.0    24.245043  C.CHRY.MV73
# 1748      1998.0    23.853322  C.CHRY.MV73
# 1749      1999.0    23.870049  C.CHRY.MV73
# 1750      2000.0    23.646931  C.CHRY.MV73
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.CHRY.MV84_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.CHRY.MV84_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.CHRY.MV84_AVERAGE.txt
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
#       wavelength  transflectance         code
# 5          255.0        5.814355  C.CHRY.MV84
# 6          256.0        5.796183  C.CHRY.MV84
# 7          257.0        5.786820  C.CHRY.MV84
# 8          258.0        5.779917  C.CHRY.MV84
# 9          259.0        5.766417  C.CHRY.MV84
# ...          ...             ...          ...
# 1746      1996.0       78.434966  C.CHRY.MV84
# 1747      1997.0       78.596375  C.CHRY.MV84
# 1748      1998.0       78.786854  C.CHRY.MV84
# 1749      1999.0       78.778666  C.CHRY.MV84
# 1750      2000.0       78.724560  C.CHRY.MV84
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.218520  C.CHRY.MV84
# 6          256.0       0.220813  C.CHRY.MV84
# 7          257.0       0.220903  C.CHRY.MV84
# 8          258.0       0.221912  C.CHRY.MV84
# 9          259.0       0.221985  C.CHRY.MV84
# ...          ...            ...          ...
# 1746      1996.0      65.029629  C.CHRY.MV84
# 1747      1997.0      65.046296  C.CHRY.MV84
# 1748      1998.0      65.200168  C.CHRY.MV84
# 1749      1999.0      65.261465  C.CHRY.MV84
# 1750      2000.0      65.265064  C.CHRY.MV84
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     5.595836  C.CHRY.MV84
# 1          256.0     5.575370  C.CHRY.MV84
# 2          257.0     5.565917  C.CHRY.MV84
# 3          258.0     5.558006  C.CHRY.MV84
# 4          259.0     5.544432  C.CHRY.MV84
# ...          ...          ...          ...
# 1741      1996.0    13.405337  C.CHRY.MV84
# 1742      1997.0    13.550079  C.CHRY.MV84
# 1743      1998.0    13.586686  C.CHRY.MV84
# 1744      1999.0    13.517201  C.CHRY.MV84
# 1745      2000.0    13.459497  C.CHRY.MV84
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    94.185645  C.CHRY.MV84
# 6          256.0    94.203817  C.CHRY.MV84
# 7          257.0    94.213180  C.CHRY.MV84
# 8          258.0    94.220083  C.CHRY.MV84
# 9          259.0    94.233583  C.CHRY.MV84
# ...          ...          ...          ...
# 1746      1996.0    21.565034  C.CHRY.MV84
# 1747      1997.0    21.403625  C.CHRY.MV84
# 1748      1998.0    21.213146  C.CHRY.MV84
# 1749      1999.0    21.221334  C.CHRY.MV84
# 1750      2000.0    21.275440  C.CHRY.MV84
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\S.BELT.1063_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\S.BELT.1063_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\S.BELT.1063_AVERAGE.txt
#       wavelength  transflectance         code
# 5          255.0       10.883634  S.BELT.1063
# 6          256.0       10.806326  S.BELT.1063
# 7          257.0       10.736001  S.BELT.1063
# 8          258.0       10.665740  S.BELT.1063
# 9          259.0       10.591912  S.BELT.1063
# ...          ...             ...          ...
# 1746      1996.0       82.076242  S.BELT.1063
# 1747      1997.0       82.099102  S.BELT.1063
# 1748      1998.0       82.094867  S.BELT.1063
# 1749      1999.0       81.911089  S.BELT.1063
# 1750      2000.0       82.077091  S.BELT.1063
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       1.049129  S.BELT.1063
# 6          256.0       0.992263  S.BELT.1063
# 7          257.0       0.941985  S.BELT.1063
# 8          258.0       0.895174  S.BELT.1063
# 9          259.0       0.850445  S.BELT.1063
# ...          ...            ...          ...
# 1746      1996.0      58.750079  S.BELT.1063
# 1747      1997.0      58.797959  S.BELT.1063
# 1748      1998.0      58.886937  S.BELT.1063
# 1749      1999.0      58.804233  S.BELT.1063
# 1750      2000.0      58.690165  S.BELT.1063
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     9.834505  S.BELT.1063
# 1          256.0     9.814063  S.BELT.1063
# 2          257.0     9.794016  S.BELT.1063
# 3          258.0     9.770566  S.BELT.1063
# 4          259.0     9.741467  S.BELT.1063
# ...          ...          ...          ...
# 1741      1996.0    23.326163  S.BELT.1063
# 1742      1997.0    23.301142  S.BELT.1063
# 1743      1998.0    23.207930  S.BELT.1063
# 1744      1999.0    23.106855  S.BELT.1063
# 1745      2000.0    23.386925  S.BELT.1063
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    89.116366  S.BELT.1063
# 6          256.0    89.193674  S.BELT.1063
# 7          257.0    89.263999  S.BELT.1063
# 8          258.0    89.334260  S.BELT.1063
# 9          259.0    89.408088  S.BELT.1063
# ...          ...          ...          ...
# 1746      1996.0    17.923758  S.BELT.1063
# 1747      1997.0    17.900898  S.BELT.1063
# 1748      1998.0    17.905133  S.BELT.1063
# 1749      1999.0    18.088911  S.BELT.1063
# 1750      2000.0    17.922909  S.BELT.1063
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\S.GLAB.0620_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\S.GLAB.0620_AVERAGE.txt
# *****
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\S.GLAB.0620_AVERAGE.txt
#       wavelength  transflectance         code
# 5          255.0        6.742059  S.GLAB.0620
# 6          256.0        6.708233  S.GLAB.0620
# 7          257.0        6.669855  S.GLAB.0620
# 8          258.0        6.633846  S.GLAB.0620
# 9          259.0        6.600871  S.GLAB.0620
# ...          ...             ...          ...
# 1746      1996.0       67.840076  S.GLAB.0620
# 1747      1997.0       67.738004  S.GLAB.0620
# 1748      1998.0       68.030402  S.GLAB.0620
# 1749      1999.0       68.146745  S.GLAB.0620
# 1750      2000.0       68.267027  S.GLAB.0620
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       2.225333  S.GLAB.0620
# 6          256.0       2.136758  S.GLAB.0620
# 7          257.0       2.054853  S.GLAB.0620
# 8          258.0       1.976260  S.GLAB.0620
# 9          259.0       1.895793  S.GLAB.0620
# ...          ...            ...          ...
# 1746      1996.0      31.329616  S.GLAB.0620
# 1747      1997.0      31.486068  S.GLAB.0620
# 1748      1998.0      31.575334  S.GLAB.0620
# 1749      1999.0      31.648029  S.GLAB.0620
# 1750      2000.0      31.755787  S.GLAB.0620
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     4.516726  S.GLAB.0620
# 1          256.0     4.571475  S.GLAB.0620
# 2          257.0     4.615002  S.GLAB.0620
# 3          258.0     4.657586  S.GLAB.0620
# 4          259.0     4.705078  S.GLAB.0620
# ...          ...          ...          ...
# 1741      1996.0    36.510461  S.GLAB.0620
# 1742      1997.0    36.251937  S.GLAB.0620
# 1743      1998.0    36.455068  S.GLAB.0620
# 1744      1999.0    36.498716  S.GLAB.0620
# 1745      2000.0    36.511240  S.GLAB.0620
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    93.257941  S.GLAB.0620
# 6          256.0    93.291767  S.GLAB.0620
# 7          257.0    93.330145  S.GLAB.0620
# 8          258.0    93.366154  S.GLAB.0620
# 9          259.0    93.399129  S.GLAB.0620
# ...          ...          ...          ...
# 1746      1996.0    32.159924  S.GLAB.0620
# 1747      1997.0    32.261996  S.GLAB.0620
# 1748      1998.0    31.969598  S.GLAB.0620
# 1749      1999.0    31.853255  S.GLAB.0620
# 1750      2000.0    31.732973  S.GLAB.0620
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\S.SIGN.PREG_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\S.SIGN.PREG_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\S.SIGN.PREG_AVERAGE.txt
#       wavelength  transflectance         code
# 5          255.0        7.746911  S.SIGN.PREG
# 6          256.0        7.720464  S.SIGN.PREG
# 7          257.0        7.695639  S.SIGN.PREG
# 8          258.0        7.678208  S.SIGN.PREG
# 9          259.0        7.672222  S.SIGN.PREG
# ...          ...             ...          ...
# 1746      1996.0       84.323226  S.SIGN.PREG
# 1747      1997.0       84.132393  S.SIGN.PREG
# 1748      1998.0       84.210789  S.SIGN.PREG
# 1749      1999.0       84.164929  S.SIGN.PREG
# 1750      2000.0       84.082250  S.SIGN.PREG
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.456638  S.SIGN.PREG
# 6          256.0       0.456875  S.SIGN.PREG
# 7          257.0       0.456188  S.SIGN.PREG
# 8          258.0       0.456671  S.SIGN.PREG
# 9          259.0       0.457112  S.SIGN.PREG
# ...          ...            ...          ...
# 1746      1996.0      63.463766  S.SIGN.PREG
# 1747      1997.0      63.474121  S.SIGN.PREG
# 1748      1998.0      63.545908  S.SIGN.PREG
# 1749      1999.0      63.667271  S.SIGN.PREG
# 1750      2000.0      63.671454  S.SIGN.PREG
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     7.290273  S.SIGN.PREG
# 1          256.0     7.263589  S.SIGN.PREG
# 2          257.0     7.239450  S.SIGN.PREG
# 3          258.0     7.221537  S.SIGN.PREG
# 4          259.0     7.215110  S.SIGN.PREG
# ...          ...          ...          ...
# 1741      1996.0    20.859460  S.SIGN.PREG
# 1742      1997.0    20.658272  S.SIGN.PREG
# 1743      1998.0    20.664881  S.SIGN.PREG
# 1744      1999.0    20.497658  S.SIGN.PREG
# 1745      2000.0    20.410796  S.SIGN.PREG
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    92.253089  S.SIGN.PREG
# 6          256.0    92.279536  S.SIGN.PREG
# 7          257.0    92.304361  S.SIGN.PREG
# 8          258.0    92.321792  S.SIGN.PREG
# 9          259.0    92.327778  S.SIGN.PREG
# ...          ...          ...          ...
# 1746      1996.0    15.676774  S.SIGN.PREG
# 1747      1997.0    15.867607  S.SIGN.PREG
# 1748      1998.0    15.789211  S.SIGN.PREG
# 1749      1999.0    15.835071  S.SIGN.PREG
# 1750      2000.0    15.917750  S.SIGN.PREG
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\NI#0002_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\NI#0002_AVERAGE.txt
# *****
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\NI#0002_AVERAGE.txt
#       wavelength  transflectance     code
# 5          255.0        8.617536  NI#0002
# 6          256.0        8.552923  NI#0002
# 7          257.0        8.491265  NI#0002
# 8          258.0        8.447033  NI#0002
# 9          259.0        8.403761  NI#0002
# ...          ...             ...      ...
# 1746      1996.0       71.568555  NI#0002
# 1747      1997.0       71.665827  NI#0002
# 1748      1998.0       71.909946  NI#0002
# 1749      1999.0       71.848702  NI#0002
# 1750      2000.0       71.957250  NI#0002
#
# [1746 rows x 3 columns]
#       wavelength  transmittance     code
# 5          255.0       0.658054  NI#0002
# 6          256.0       0.643769  NI#0002
# 7          257.0       0.628457  NI#0002
# 8          258.0       0.616332  NI#0002
# 9          259.0       0.603511  NI#0002
# ...          ...            ...      ...
# 1746      1996.0      45.560104  NI#0002
# 1747      1997.0      45.717775  NI#0002
# 1748      1998.0      45.726448  NI#0002
# 1749      1999.0      45.724545  NI#0002
# 1750      2000.0      45.749986  NI#0002
#
# [1746 rows x 3 columns]
#       wavelength  reflectance     code
# 0          255.0     7.959482  NI#0002
# 1          256.0     7.909154  NI#0002
# 2          257.0     7.862809  NI#0002
# 3          258.0     7.830702  NI#0002
# 4          259.0     7.800250  NI#0002
# ...          ...          ...      ...
# 1741      1996.0    26.008452  NI#0002
# 1742      1997.0    25.948052  NI#0002
# 1743      1998.0    26.183499  NI#0002
# 1744      1999.0    26.124157  NI#0002
# 1745      2000.0    26.207264  NI#0002
#
# [1746 rows x 3 columns]
#       wavelength  absorptance     code
# 5          255.0    91.382464  NI#0002
# 6          256.0    91.447077  NI#0002
# 7          257.0    91.508735  NI#0002
# 8          258.0    91.552967  NI#0002
# 9          259.0    91.596239  NI#0002
# ...          ...          ...      ...
# 1746      1996.0    28.431445  NI#0002
# 1747      1997.0    28.334173  NI#0002
# 1748      1998.0    28.090054  NI#0002
# 1749      1999.0    28.151298  NI#0002
# 1750      2000.0    28.042750  NI#0002
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\P.GRAT.3610_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\P.GRAT.3610_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\P.GRAT.3610_AVERAGE.txt
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
#       wavelength  transflectance         code
# 5          255.0        7.040666  P.GRAT.3610
# 6          256.0        6.996544  P.GRAT.3610
# 7          257.0        6.952930  P.GRAT.3610
# 8          258.0        6.915308  P.GRAT.3610
# 9          259.0        6.887496  P.GRAT.3610
# ...          ...             ...          ...
# 1746      1996.0       71.001739  P.GRAT.3610
# 1747      1997.0       71.101717  P.GRAT.3610
# 1748      1998.0       71.274915  P.GRAT.3610
# 1749      1999.0       71.399588  P.GRAT.3610
# 1750      2000.0       71.471892  P.GRAT.3610
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.134627  P.GRAT.3610
# 6          256.0       0.135655  P.GRAT.3610
# 7          257.0       0.140664  P.GRAT.3610
# 8          258.0       0.142954  P.GRAT.3610
# 9          259.0       0.147513  P.GRAT.3610
# ...          ...            ...          ...
# 1746      1996.0      45.854959  P.GRAT.3610
# 1747      1997.0      45.836199  P.GRAT.3610
# 1748      1998.0      45.838947  P.GRAT.3610
# 1749      1999.0      45.847352  P.GRAT.3610
# 1750      2000.0      45.872884  P.GRAT.3610
#
# [1746 rows x 3 columns]
#       wavelength  reflectance         code
# 0          255.0     6.906039  P.GRAT.3610
# 1          256.0     6.860889  P.GRAT.3610
# 2          257.0     6.812266  P.GRAT.3610
# 3          258.0     6.772353  P.GRAT.3610
# 4          259.0     6.739983  P.GRAT.3610
# ...          ...          ...          ...
# 1741      1996.0    25.146780  P.GRAT.3610
# 1742      1997.0    25.265517  P.GRAT.3610
# 1743      1998.0    25.435968  P.GRAT.3610
# 1744      1999.0    25.552236  P.GRAT.3610
# 1745      2000.0    25.599008  P.GRAT.3610
#
# [1746 rows x 3 columns]
#       wavelength  absorptance         code
# 5          255.0    92.959334  P.GRAT.3610
# 6          256.0    93.003456  P.GRAT.3610
# 7          257.0    93.047070  P.GRAT.3610
# 8          258.0    93.084692  P.GRAT.3610
# 9          259.0    93.112504  P.GRAT.3610
# ...          ...          ...          ...
# 1746      1996.0    28.998261  P.GRAT.3610
# 1747      1997.0    28.898283  P.GRAT.3610
# 1748      1998.0    28.725085  P.GRAT.3610
# 1749      1999.0    28.600412  P.GRAT.3610
# 1750      2000.0    28.528108  P.GRAT.3610
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\MACRASPIS.SP_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\MACRASPIS.SP_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\MACRASPIS.SP_AVERAGE.txt
#       wavelength  transflectance          code
# 5          255.0        8.091157  MACRASPIS.SP
# 6          256.0        8.036242  MACRASPIS.SP
# 7          257.0        7.966846  MACRASPIS.SP
# 8          258.0        7.921807  MACRASPIS.SP
# 9          259.0        7.872426  MACRASPIS.SP
# ...          ...             ...           ...
# 1746      1996.0       81.309042  MACRASPIS.SP
# 1747      1997.0       81.395263  MACRASPIS.SP
# 1748      1998.0       81.633419  MACRASPIS.SP
# 1749      1999.0       81.660724  MACRASPIS.SP
# 1750      2000.0       81.757074  MACRASPIS.SP
#
# [1746 rows x 3 columns]
#       wavelength  transmittance          code
# 5          255.0       0.337945  MACRASPIS.SP
# 6          256.0       0.338086  MACRASPIS.SP
# 7          257.0       0.339296  MACRASPIS.SP
# 8          258.0       0.338784  MACRASPIS.SP
# 9          259.0       0.340692  MACRASPIS.SP
# ...          ...            ...           ...
# 1746      1996.0      65.800404  MACRASPIS.SP
# 1747      1997.0      65.839570  MACRASPIS.SP
# 1748      1998.0      65.920690  MACRASPIS.SP
# 1749      1999.0      66.032506  MACRASPIS.SP
# 1750      2000.0      66.088987  MACRASPIS.SP
#
# [1746 rows x 3 columns]
#       wavelength  reflectance          code
# 0          255.0     7.753212  MACRASPIS.SP
# 1          256.0     7.698156  MACRASPIS.SP
# 2          257.0     7.627551  MACRASPIS.SP
# 3          258.0     7.583023  MACRASPIS.SP
# 4          259.0     7.531734  MACRASPIS.SP
# ...          ...          ...           ...
# 1741      1996.0    15.508637  MACRASPIS.SP
# 1742      1997.0    15.555692  MACRASPIS.SP
# 1743      1998.0    15.712729  MACRASPIS.SP
# 1744      1999.0    15.628218  MACRASPIS.SP
# 1745      2000.0    15.668087  MACRASPIS.SP
#
# [1746 rows x 3 columns]
#       wavelength  absorptance          code
# 5          255.0    91.908843  MACRASPIS.SP
# 6          256.0    91.963758  MACRASPIS.SP
# 7          257.0    92.033154  MACRASPIS.SP
# 8          258.0    92.078193  MACRASPIS.SP
# 9          259.0    92.127574  MACRASPIS.SP
# ...          ...          ...           ...
# 1746      1996.0    18.690958  MACRASPIS.SP
# 1747      1997.0    18.604737  MACRASPIS.SP
# 1748      1998.0    18.366581  MACRASPIS.SP
# 1749      1999.0    18.339276  MACRASPIS.SP
# 1750      2000.0    18.242926  MACRASPIS.SP
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\NI#0001_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\NI#0001_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\NI#0001_AVERAGE.txt
#       wavelength  transflectance     code
# 5          255.0        8.292390  NI#0001
# 6          256.0        8.236826  NI#0001
# 7          257.0        8.185871  NI#0001
# 8          258.0        8.146910  NI#0001
# 9          259.0        8.116279  NI#0001
# ...          ...             ...      ...
# 1746      1996.0       79.882953  NI#0001
# 1747      1997.0       79.809342  NI#0001
# 1748      1998.0       79.990848  NI#0001
# 1749      1999.0       80.090843  NI#0001
# 1750      2000.0       80.159196  NI#0001
#
# [1746 rows x 3 columns]
#       wavelength  transmittance     code
# 5          255.0       8.200203  NI#0001
# 6          256.0       7.945619  NI#0001
# 7          257.0       7.696608  NI#0001
# 8          258.0       7.452043  NI#0001
# 9          259.0       7.223514  NI#0001
# ...          ...            ...      ...
# 1746      1996.0      54.630119  NI#0001
# 1747      1997.0      54.644309  NI#0001
# 1748      1998.0      54.728939  NI#0001
# 1749      1999.0      54.849105  NI#0001
# 1750      2000.0      54.949467  NI#0001
#
# [1746 rows x 3 columns]
#       wavelength  reflectance     code
# 0          255.0     0.092188  NI#0001
# 1          256.0     0.291207  NI#0001
# 2          257.0     0.489263  NI#0001
# 3          258.0     0.694868  NI#0001
# 4          259.0     0.892765  NI#0001
# ...          ...          ...      ...
# 1741      1996.0    25.252834  NI#0001
# 1742      1997.0    25.165033  NI#0001
# 1743      1998.0    25.261909  NI#0001
# 1744      1999.0    25.241737  NI#0001
# 1745      2000.0    25.209729  NI#0001
#
# [1746 rows x 3 columns]
#       wavelength  absorptance     code
# 5          255.0    91.707610  NI#0001
# 6          256.0    91.763174  NI#0001
# 7          257.0    91.814129  NI#0001
# 8          258.0    91.853090  NI#0001
# 9          259.0    91.883721  NI#0001
# ...          ...          ...      ...
# 1746      1996.0    20.117047  NI#0001
# 1747      1997.0    20.190658  NI#0001
# 1748      1998.0    20.009152  NI#0001
# 1749      1999.0    19.909157  NI#0001
# 1750      2000.0    19.840804  NI#0001
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\M.HIRT.DIUR_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\M.HIRT.DIUR_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\M.HIRT.DIUR_AVERAGE.txt
#       wavelength  transflectance         code
# 5          255.0        5.575432  M.HIRT.DIUR
# 6          256.0        5.546372  M.HIRT.DIUR
# 7          257.0        5.531156  M.HIRT.DIUR
# 8          258.0        5.503967  M.HIRT.DIUR
# 9          259.0        5.486940  M.HIRT.DIUR
# ...          ...             ...          ...
# 1746      1996.0       66.042625  M.HIRT.DIUR
# 1747      1997.0       66.278365  M.HIRT.DIUR
# 1748      1998.0       66.682987  M.HIRT.DIUR
# 1749      1999.0       66.804418  M.HIRT.DIUR
# 1750      2000.0       66.905448  M.HIRT.DIUR
#
# [1746 rows x 3 columns]
#       wavelength  transmittance         code
# 5          255.0       0.259084  M.HIRT.DIUR
# 6          256.0       0.259574  M.HIRT.DIUR
# 7          257.0       0.259865  M.HIRT.DIUR
# 8          258.0       0.261075  M.HIRT.DIUR
# 9          259.0       0.265572  M.HIRT.DIUR
# ...          ...            ...          ...
# 1746      1996.0      32.906999  M.HIRT.DIUR
# 1747      1997.0      33.007097  M.HIRT.DIUR
# 1748      1998.0      33.011530  M.HIRT.DIUR
# 1749      1999.0      33.101492  M.HIRT.DIUR
# ...
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\PELID.001_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\PELID.001_AVERAGE.txt
#       wavelength  transflectance       code
# 5          255.0        6.547808  PELID.001
# 6          256.0        6.515745  PELID.001
# 7          257.0        6.495388  PELID.001
# 8          258.0        6.461941  PELID.001
# 9          259.0        6.439642  PELID.001
# ...          ...             ...        ...
# 1746      1996.0       69.543280  PELID.001
# 1747      1997.0       69.466963  PELID.001
# 1748      1998.0       69.897214  PELID.001
# 1749      1999.0       70.015739  PELID.001
# 1750      2000.0       70.196022  PELID.001
#
# [1746 rows x 3 columns]
#       wavelength  transmittance       code
# 5          255.0       0.224503  PELID.001
# 6          256.0       0.225879  PELID.001
# 7          257.0       0.226723  PELID.001
# 8          258.0       0.228663  PELID.001
# 9          259.0       0.231118  PELID.001
# ...          ...            ...        ...
# 1746      1996.0      33.673116  PELID.001
# 1747      1997.0      33.702853  PELID.001
# 1748      1998.0      33.710917  PELID.001
# 1749      1999.0      33.778951  PELID.001
# 1750      2000.0      33.761299  PELID.001
#
# [1746 rows x 3 columns]
#       wavelength  reflectance       code
# 0          255.0     6.323305  PELID.001
# 1          256.0     6.289865  PELID.001
# 2          257.0     6.268665  PELID.001
# 3          258.0     6.233278  PELID.001
# 4          259.0     6.208523  PELID.001
# ...          ...          ...        ...
# 1741      1996.0    35.870164  PELID.001
# 1742      1997.0    35.764110  PELID.001
# 1743      1998.0    36.186296  PELID.001
# 1744      1999.0    36.236788  PELID.001
# 1745      2000.0    36.434723  PELID.001
#
# [1746 rows x 3 columns]
#       wavelength  absorptance       code
# 5          255.0    93.452192  PELID.001
# 6          256.0    93.484255  PELID.001
# 7          257.0    93.504612  PELID.001
# 8          258.0    93.538059  PELID.001
# 9          259.0    93.560358  PELID.001
# ...          ...          ...        ...
# 1746      1996.0    30.456720  PELID.001
# 1747      1997.0    30.533037  PELID.001
# 1748      1998.0    30.102786  PELID.001
# 1749      1999.0    29.984261  PELID.001
# 1750      2000.0    29.803978  PELID.001
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\PLATY.001_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\PLATY.001_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\PLATY.001_AVERAGE.txt
#       wavelength  transflectance       code
# 5          255.0        6.991599  PLATY.001
# 6          256.0        6.954208  PLATY.001
# 7          257.0        6.917301  PLATY.001
# 8          258.0        6.893654  PLATY.001
# 9          259.0        6.857137  PLATY.001
# ...          ...             ...        ...
# 1746      1996.0       67.616411  PLATY.001
# 1747      1997.0       68.218309  PLATY.001
# 1748      1998.0       68.767880  PLATY.001
# 1749      1999.0       68.958797  PLATY.001
# 1750      2000.0       69.172209  PLATY.001
#
# [1746 rows x 3 columns]
#       wavelength  transmittance       code
# 5          255.0       0.158064  PLATY.001
# 6          256.0       0.159503  PLATY.001
# 7          257.0       0.161631  PLATY.001
# 8          258.0       0.163812  PLATY.001
# 9          259.0       0.167938  PLATY.001
# ...          ...            ...        ...
# 1746      1996.0      24.185272  PLATY.001
# 1747      1997.0      24.200882  PLATY.001
# 1748      1998.0      24.306317  PLATY.001
# 1749      1999.0      24.395981  PLATY.001
# 1750      2000.0      24.438270  PLATY.001
#
# [1746 rows x 3 columns]
#       wavelength  reflectance       code
# 0          255.0     6.833535  PLATY.001
# 1          256.0     6.794705  PLATY.001
# 2          257.0     6.755670  PLATY.001
# 3          258.0     6.729842  PLATY.001
# 4          259.0     6.689199  PLATY.001
# ...          ...          ...        ...
# 1741      1996.0    43.431139  PLATY.001
# 1742      1997.0    44.017426  PLATY.001
# 1743      1998.0    44.461563  PLATY.001
# 1744      1999.0    44.562816  PLATY.001
# 1745      2000.0    44.733938  PLATY.001
#
# [1746 rows x 3 columns]
#       wavelength  absorptance       code
# 5          255.0    93.008401  PLATY.001
# 6          256.0    93.045792  PLATY.001
# 7          257.0    93.082699  PLATY.001
# 8          258.0    93.106346  PLATY.001
# 9          259.0    93.142863  PLATY.001
# ...          ...          ...        ...
# 1746      1996.0    32.383589  PLATY.001
# 1747      1997.0    31.781691  PLATY.001
# 1748      1998.0    31.232120  PLATY.001
# 1749      1999.0    31.041203  PLATY.001
# 1750      2000.0    30.827791  PLATY.001
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\PELID.002_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\PELID.002_AVERAGE.txt
# *****
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code
# C:\Users\esteb\anaconda3\envs\DataAnalysis\Lib\site-packages\pandas\plotting\_matplotlib\core.py:580: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\PELID.002_AVERAGE.txt
#       wavelength  transflectance       code
# 5          255.0        6.307133  PELID.002
# 6          256.0        6.281617  PELID.002
# 7          257.0        6.261898  PELID.002
# 8          258.0        6.237263  PELID.002
# 9          259.0        6.209287  PELID.002
# ...          ...             ...        ...
# 1746      1996.0       79.120624  PELID.002
# 1747      1997.0       79.516862  PELID.002
# 1748      1998.0       79.869250  PELID.002
# 1749      1999.0       79.916163  PELID.002
# 1750      2000.0       79.815983  PELID.002
#
# [1746 rows x 3 columns]
#       wavelength  transmittance       code
# 5          255.0       0.213644  PELID.002
# 6          256.0       0.215950  PELID.002
# 7          257.0       0.218879  PELID.002
# 8          258.0       0.221505  PELID.002
# 9          259.0       0.223231  PELID.002
# ...          ...            ...        ...
# 1746      1996.0      57.979641  PELID.002
# 1747      1997.0      58.037290  PELID.002
# 1748      1998.0      58.090340  PELID.002
# 1749      1999.0      58.157117  PELID.002
# 1750      2000.0      58.204897  PELID.002
#
# [1746 rows x 3 columns]
#       wavelength  reflectance       code
# 0          255.0     6.093489  PELID.002
# 1          256.0     6.065668  PELID.002
# 2          257.0     6.043020  PELID.002
# 3          258.0     6.015757  PELID.002
# 4          259.0     5.986056  PELID.002
# ...          ...          ...        ...
# 1741      1996.0    21.140982  PELID.002
# 1742      1997.0    21.479572  PELID.002
# 1743      1998.0    21.778910  PELID.002
# 1744      1999.0    21.759046  PELID.002
# 1745      2000.0    21.611085  PELID.002
#
# [1746 rows x 3 columns]
#       wavelength  absorptance       code
# 5          255.0    93.692867  PELID.002
# 6          256.0    93.718383  PELID.002
# 7          257.0    93.738102  PELID.002
# 8          258.0    93.762737  PELID.002
# 9          259.0    93.790713  PELID.002
# ...          ...          ...        ...
# 1746      1996.0    20.879376  PELID.002
# 1747      1997.0    20.483138  PELID.002
# 1748      1998.0    20.130750  PELID.002
# 1749      1999.0    20.083837  PELID.002
# 1750      2000.0    20.184017  PELID.002
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.BOUC.INB5610_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.BOUC.INB5610_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.BOUC.INB5610_AVERAGE.txt
#       wavelength  transflectance            code
# 5          255.0        6.279243  C.BOUC.INB5610
# 6          256.0        6.234452  C.BOUC.INB5610
# 7          257.0        6.203099  C.BOUC.INB5610
# 8          258.0        6.179720  C.BOUC.INB5610
# 9          259.0        6.150457  C.BOUC.INB5610
# ...          ...             ...             ...
# 1746      1996.0       65.447755  C.BOUC.INB5610
# 1747      1997.0       65.607544  C.BOUC.INB5610
# 1748      1998.0       65.783041  C.BOUC.INB5610
# 1749      1999.0       65.776963  C.BOUC.INB5610
# 1750      2000.0       65.757225  C.BOUC.INB5610
#
# [1746 rows x 3 columns]
#       wavelength  transmittance            code
# 5          255.0       0.203556  C.BOUC.INB5610
# 6          256.0       0.202905  C.BOUC.INB5610
# 7          257.0       0.204641  C.BOUC.INB5610
# 8          258.0       0.207576  C.BOUC.INB5610
# 9          259.0       0.212184  C.BOUC.INB5610
# ...          ...            ...             ...
# 1746      1996.0      41.359007  C.BOUC.INB5610
# 1747      1997.0      41.362016  C.BOUC.INB5610
# 1748      1998.0      41.396218  C.BOUC.INB5610
# 1749      1999.0      41.444461  C.BOUC.INB5610
# 1750      2000.0      41.515045  C.BOUC.INB5610
#
# [1746 rows x 3 columns]
#       wavelength  reflectance            code
# 0          255.0     6.075687  C.BOUC.INB5610
# 1          256.0     6.031547  C.BOUC.INB5610
# 2          257.0     5.998458  C.BOUC.INB5610
# 3          258.0     5.972144  C.BOUC.INB5610
# 4          259.0     5.938273  C.BOUC.INB5610
# ...          ...          ...             ...
# 1741      1996.0    24.088748  C.BOUC.INB5610
# 1742      1997.0    24.245528  C.BOUC.INB5610
# 1743      1998.0    24.386823  C.BOUC.INB5610
# 1744      1999.0    24.332501  C.BOUC.INB5610
# 1745      2000.0    24.242180  C.BOUC.INB5610
#
# [1746 rows x 3 columns]
#       wavelength  absorptance            code
# 5          255.0    93.720757  C.BOUC.INB5610
# 6          256.0    93.765548  C.BOUC.INB5610
# 7          257.0    93.796901  C.BOUC.INB5610
# 8          258.0    93.820280  C.BOUC.INB5610
# 9          259.0    93.849543  C.BOUC.INB5610
# ...          ...          ...             ...
# 1746      1996.0    34.552245  C.BOUC.INB5610
# 1747      1997.0    34.392456  C.BOUC.INB5610
# 1748      1998.0    34.216959  C.BOUC.INB5610
# 1749      1999.0    34.223037  C.BOUC.INB5610
# 1750      2000.0    34.242775  C.BOUC.INB5610
#
# [1746 rows x 3 columns]
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.BOUC.INB5423_AVERAGE.txt
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSMITTANCE\transmittance\average\C.BOUC.INB5423_AVERAGE.txt
# *****
# reflectance.file
# E:\CICIMA\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023_Q4_TRANSMITTANCE_AND_TRANSFLECTANCE\2023NOV_TRANSFLECTANCE\transflectance\average\C.BOUC.INB5423_AVERAGE.txt
#       wavelength  transflectance            code
# 5          255.0        6.504291  C.BOUC.INB5423
# 6          256.0        6.461764  C.BOUC.INB5423
# 7          257.0        6.423490  C.BOUC.INB5423
# 8          258.0        6.398372  C.BOUC.INB5423
# 9          259.0        6.372060  C.BOUC.INB5423
# ...          ...             ...             ...
# 1746      1996.0       65.014961  C.BOUC.INB5423
# 1747      1997.0       65.216681  C.BOUC.INB5423
# 1748      1998.0       65.314815  C.BOUC.INB5423
# 1749      1999.0       65.132809  C.BOUC.INB5423
# 1750      2000.0       64.931478  C.BOUC.INB5423
#
# [1746 rows x 3 columns]
#       wavelength  transmittance            code
# 5          255.0       0.260778  C.BOUC.INB5423
# 6          256.0       0.258541  C.BOUC.INB5423
# 7          257.0       0.258746  C.BOUC.INB5423
# 8          258.0       0.259757  C.BOUC.INB5423
# 9          259.0       0.258157  C.BOUC.INB5423
# ...          ...            ...             ...
# 1746      1996.0      38.045146  C.BOUC.INB5423
# 1747      1997.0      37.995852  C.BOUC.INB5423
# 1748      1998.0      38.171344  C.BOUC.INB5423
# 1749      1999.0      38.197564  C.BOUC.INB5423
# 1750      2000.0      38.101513  C.BOUC.INB5423
#
# [1746 rows x 3 columns]
#       wavelength  reflectance            code
# 0          255.0     6.243513  C.BOUC.INB5423
# 1          256.0     6.203223  C.BOUC.INB5423
# 2          257.0     6.164744  C.BOUC.INB5423
# 3          258.0     6.138616  C.BOUC.INB5423
# 4          259.0     6.113904  C.BOUC.INB5423
# ...          ...          ...             ...
# 1741      1996.0    26.969815  C.BOUC.INB5423
# 1742      1997.0    27.220829  C.BOUC.INB5423
# 1743      1998.0    27.143471  C.BOUC.INB5423
# 1744      1999.0    26.935246  C.BOUC.INB5423
# 1745      2000.0    26.829965  C.BOUC.INB5423
#
# [1746 rows x 3 columns]
#       wavelength  absorptance            code
# 5          255.0    93.495709  C.BOUC.INB5423
# 6          256.0    93.538236  C.BOUC.INB5423
# 7          257.0    93.576510  C.BOUC.INB5423
# 8          258.0    93.601628  C.BOUC.INB5423
# 9          259.0    93.627940  C.BOUC.INB5423
# ...          ...          ...             ...
# 1746      1996.0    34.985039  C.BOUC.INB5423
# 1747      1997.0    34.783319  C.BOUC.INB5423
# 1748      1998.0    34.685185  C.BOUC.INB5423
# 1749      1999.0    34.867191  C.BOUC.INB5423
# 1750      2000.0    35.068522  C.BOUC.INB5423
#
# [1746 rows x 3 columns]
# C:\Users\esteb\AppData\Local\Temp\ipykernel_18268\456827627.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflectance_df["code"] = code

# %%
absorptance_dataframes
# Out:
# [      wavelength  absorptance         code
#  5          255.0    94.246149  C.KALI.LA22
#  6          256.0    94.278226  C.KALI.LA22
#  7          257.0    94.304441  C.KALI.LA22
#  8          258.0    94.323133  C.KALI.LA22
#  9          259.0    94.341188  C.KALI.LA22
#  ...          ...          ...          ...
#  1746      1996.0    26.451642  C.KALI.LA22
#  1747      1997.0    26.059093  C.KALI.LA22
#  1748      1998.0    25.664986  C.KALI.LA22
#  1749      1999.0    25.556313  C.KALI.LA22
#  1750      2000.0    25.329440  C.KALI.LA22
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    92.777358  C.RESP.MV23
#  6          256.0    92.804088  C.RESP.MV23
#  7          257.0    92.836169  C.RESP.MV23
#  8          258.0    92.863644  C.RESP.MV23
#  9          259.0    92.875030  C.RESP.MV23
#  ...          ...          ...          ...
#  1746      1996.0    27.195568  C.RESP.MV23
#  1747      1997.0    26.778653  C.RESP.MV23
#  1748      1998.0    26.487744  C.RESP.MV23
#  1749      1999.0    26.382219  C.RESP.MV23
#  1750      2000.0    26.221556  C.RESP.MV23
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    93.264366  C.CUPR.MV23
#  6          256.0    93.298363  C.CUPR.MV23
#  7          257.0    93.327500  C.CUPR.MV23
#  8          258.0    93.350558  C.CUPR.MV23
#  9          259.0    93.382419  C.CUPR.MV23
#  ...          ...          ...          ...
#  1746      1996.0    20.146587  C.CUPR.MV23
#  1747      1997.0    19.955743  C.CUPR.MV23
#  1748      1998.0    19.622956  C.CUPR.MV23
#  1749      1999.0    19.754987  C.CUPR.MV23
#  1750      2000.0    19.626199  C.CUPR.MV23
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    93.757898  C.AURI.INBI
#  6          256.0    93.781855  C.AURI.INBI
#  7          257.0    93.799827  C.AURI.INBI
#  8          258.0    93.829158  C.AURI.INBI
#  9          259.0    93.858183  C.AURI.INBI
#  ...          ...          ...          ...
#  1746      1996.0    29.615803  C.AURI.INBI
#  1747      1997.0    29.421502  C.AURI.INBI
#  1748      1998.0    29.063255  C.AURI.INBI
#  1749      1999.0    28.864509  C.AURI.INBI
#  1750      2000.0    28.702340  C.AURI.INBI
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    93.939524  C.CHRY.6713
#  6          256.0    93.961288  C.CHRY.6713
#  7          257.0    93.983521  C.CHRY.6713
#  8          258.0    94.007609  C.CHRY.6713
#  9          259.0    94.045565  C.CHRY.6713
#  ...          ...          ...          ...
#  1746      1996.0    33.146918  C.CHRY.6713
#  1747      1997.0    33.059307  C.CHRY.6713
#  1748      1998.0    32.822556  C.CHRY.6713
#  1749      1999.0    32.806427  C.CHRY.6713
#  1750      2000.0    32.879442  C.CHRY.6713
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    93.920062  C.OPTI.8.17
#  6          256.0    93.949765  C.OPTI.8.17
#  7          257.0    93.973722  C.OPTI.8.17
#  8          258.0    93.988783  C.OPTI.8.17
#  9          259.0    94.011396  C.OPTI.8.17
#  ...          ...          ...          ...
#  1746      1996.0    34.103322  C.OPTI.8.17
#  1747      1997.0    33.981919  C.OPTI.8.17
#  1748      1998.0    33.811114  C.OPTI.8.17
#  1749      1999.0    33.686401  C.OPTI.8.17
#  1750      2000.0    33.570048  C.OPTI.8.17
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    93.596806  C.CHRY.MV73
#  6          256.0    93.613845  C.CHRY.MV73
#  7          257.0    93.639880  C.CHRY.MV73
#  8          258.0    93.661276  C.CHRY.MV73
#  9          259.0    93.694971  C.CHRY.MV73
#  ...          ...          ...          ...
#  1746      1996.0    24.390058  C.CHRY.MV73
#  1747      1997.0    24.245043  C.CHRY.MV73
#  1748      1998.0    23.853322  C.CHRY.MV73
#  1749      1999.0    23.870049  C.CHRY.MV73
#  1750      2000.0    23.646931  C.CHRY.MV73
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    94.185645  C.CHRY.MV84
#  6          256.0    94.203817  C.CHRY.MV84
#  7          257.0    94.213180  C.CHRY.MV84
#  8          258.0    94.220083  C.CHRY.MV84
#  9          259.0    94.233583  C.CHRY.MV84
#  ...          ...          ...          ...
#  1746      1996.0    21.565034  C.CHRY.MV84
#  1747      1997.0    21.403625  C.CHRY.MV84
#  1748      1998.0    21.213146  C.CHRY.MV84
#  1749      1999.0    21.221334  C.CHRY.MV84
#  1750      2000.0    21.275440  C.CHRY.MV84
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    89.116366  S.BELT.1063
#  6          256.0    89.193674  S.BELT.1063
#  7          257.0    89.263999  S.BELT.1063
#  8          258.0    89.334260  S.BELT.1063
#  9          259.0    89.408088  S.BELT.1063
#  ...          ...          ...          ...
#  1746      1996.0    17.923758  S.BELT.1063
#  1747      1997.0    17.900898  S.BELT.1063
#  1748      1998.0    17.905133  S.BELT.1063
#  1749      1999.0    18.088911  S.BELT.1063
#  1750      2000.0    17.922909  S.BELT.1063
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    93.257941  S.GLAB.0620
#  6          256.0    93.291767  S.GLAB.0620
#  7          257.0    93.330145  S.GLAB.0620
#  8          258.0    93.366154  S.GLAB.0620
#  9          259.0    93.399129  S.GLAB.0620
#  ...          ...          ...          ...
#  1746      1996.0    32.159924  S.GLAB.0620
#  1747      1997.0    32.261996  S.GLAB.0620
#  1748      1998.0    31.969598  S.GLAB.0620
#  1749      1999.0    31.853255  S.GLAB.0620
#  1750      2000.0    31.732973  S.GLAB.0620
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    92.253089  S.SIGN.PREG
#  6          256.0    92.279536  S.SIGN.PREG
#  7          257.0    92.304361  S.SIGN.PREG
#  8          258.0    92.321792  S.SIGN.PREG
#  9          259.0    92.327778  S.SIGN.PREG
#  ...          ...          ...          ...
#  1746      1996.0    15.676774  S.SIGN.PREG
#  1747      1997.0    15.867607  S.SIGN.PREG
#  1748      1998.0    15.789211  S.SIGN.PREG
#  1749      1999.0    15.835071  S.SIGN.PREG
#  1750      2000.0    15.917750  S.SIGN.PREG
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance     code
#  5          255.0    91.382464  NI#0002
#  6          256.0    91.447077  NI#0002
#  7          257.0    91.508735  NI#0002
#  8          258.0    91.552967  NI#0002
#  9          259.0    91.596239  NI#0002
#  ...          ...          ...      ...
#  1746      1996.0    28.431445  NI#0002
#  1747      1997.0    28.334173  NI#0002
#  1748      1998.0    28.090054  NI#0002
#  1749      1999.0    28.151298  NI#0002
#  1750      2000.0    28.042750  NI#0002
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    92.959334  P.GRAT.3610
#  6          256.0    93.003456  P.GRAT.3610
#  7          257.0    93.047070  P.GRAT.3610
#  8          258.0    93.084692  P.GRAT.3610
#  9          259.0    93.112504  P.GRAT.3610
#  ...          ...          ...          ...
#  1746      1996.0    28.998261  P.GRAT.3610
#  1747      1997.0    28.898283  P.GRAT.3610
#  1748      1998.0    28.725085  P.GRAT.3610
#  1749      1999.0    28.600412  P.GRAT.3610
#  1750      2000.0    28.528108  P.GRAT.3610
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance          code
#  5          255.0    91.908843  MACRASPIS.SP
#  6          256.0    91.963758  MACRASPIS.SP
#  7          257.0    92.033154  MACRASPIS.SP
#  8          258.0    92.078193  MACRASPIS.SP
#  9          259.0    92.127574  MACRASPIS.SP
#  ...          ...          ...           ...
#  1746      1996.0    18.690958  MACRASPIS.SP
#  1747      1997.0    18.604737  MACRASPIS.SP
#  1748      1998.0    18.366581  MACRASPIS.SP
#  1749      1999.0    18.339276  MACRASPIS.SP
#  1750      2000.0    18.242926  MACRASPIS.SP
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance     code
#  5          255.0    91.707610  NI#0001
#  6          256.0    91.763174  NI#0001
#  7          257.0    91.814129  NI#0001
#  8          258.0    91.853090  NI#0001
#  9          259.0    91.883721  NI#0001
#  ...          ...          ...      ...
#  1746      1996.0    20.117047  NI#0001
#  1747      1997.0    20.190658  NI#0001
#  1748      1998.0    20.009152  NI#0001
#  1749      1999.0    19.909157  NI#0001
#  1750      2000.0    19.840804  NI#0001
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    94.424568  M.HIRT.DIUR
#  6          256.0    94.453628  M.HIRT.DIUR
#  7          257.0    94.468844  M.HIRT.DIUR
#  8          258.0    94.496033  M.HIRT.DIUR
#  9          259.0    94.513060  M.HIRT.DIUR
#  ...          ...          ...          ...
#  1746      1996.0    33.957375  M.HIRT.DIUR
#  1747      1997.0    33.721635  M.HIRT.DIUR
#  1748      1998.0    33.317013  M.HIRT.DIUR
#  1749      1999.0    33.195582  M.HIRT.DIUR
#  1750      2000.0    33.094552  M.HIRT.DIUR
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance         code
#  5          255.0    93.490712  C.BOUC.CO23
#  6          256.0    93.519581  C.BOUC.CO23
#  7          257.0    93.548368  C.BOUC.CO23
#  8          258.0    93.561281  C.BOUC.CO23
#  9          259.0    93.583491  C.BOUC.CO23
#  ...          ...          ...          ...
#  1746      1996.0    20.671727  C.BOUC.CO23
#  1747      1997.0    20.708802  C.BOUC.CO23
#  1748      1998.0    20.329185  C.BOUC.CO23
#  1749      1999.0    20.353572  C.BOUC.CO23
#  1750      2000.0    20.348670  C.BOUC.CO23
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance       code
#  5          255.0    93.452192  PELID.001
#  6          256.0    93.484255  PELID.001
#  7          257.0    93.504612  PELID.001
#  8          258.0    93.538059  PELID.001
#  9          259.0    93.560358  PELID.001
#  ...          ...          ...        ...
#  1746      1996.0    30.456720  PELID.001
#  1747      1997.0    30.533037  PELID.001
#  1748      1998.0    30.102786  PELID.001
#  1749      1999.0    29.984261  PELID.001
#  1750      2000.0    29.803978  PELID.001
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance       code
#  5          255.0    93.008401  PLATY.001
#  6          256.0    93.045792  PLATY.001
#  7          257.0    93.082699  PLATY.001
#  8          258.0    93.106346  PLATY.001
#  9          259.0    93.142863  PLATY.001
#  ...          ...          ...        ...
#  1746      1996.0    32.383589  PLATY.001
#  1747      1997.0    31.781691  PLATY.001
#  1748      1998.0    31.232120  PLATY.001
#  1749      1999.0    31.041203  PLATY.001
#  1750      2000.0    30.827791  PLATY.001
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance       code
#  5          255.0    93.692867  PELID.002
#  6          256.0    93.718383  PELID.002
#  7          257.0    93.738102  PELID.002
#  8          258.0    93.762737  PELID.002
#  9          259.0    93.790713  PELID.002
#  ...          ...          ...        ...
#  1746      1996.0    20.879376  PELID.002
#  1747      1997.0    20.483138  PELID.002
#  1748      1998.0    20.130750  PELID.002
#  1749      1999.0    20.083837  PELID.002
#  1750      2000.0    20.184017  PELID.002
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance            code
#  5          255.0    93.720757  C.BOUC.INB5610
#  6          256.0    93.765548  C.BOUC.INB5610
#  7          257.0    93.796901  C.BOUC.INB5610
#  8          258.0    93.820280  C.BOUC.INB5610
#  9          259.0    93.849543  C.BOUC.INB5610
#  ...          ...          ...             ...
#  1746      1996.0    34.552245  C.BOUC.INB5610
#  1747      1997.0    34.392456  C.BOUC.INB5610
#  1748      1998.0    34.216959  C.BOUC.INB5610
#  1749      1999.0    34.223037  C.BOUC.INB5610
#  1750      2000.0    34.242775  C.BOUC.INB5610
#
#  [1746 rows x 3 columns],
#        wavelength  absorptance            code
#  5          255.0    93.495709  C.BOUC.INB5423
#  6          256.0    93.538236  C.BOUC.INB5423
#  7          257.0    93.576510  C.BOUC.INB5423
#  8          258.0    93.601628  C.BOUC.INB5423
#  9          259.0    93.627940  C.BOUC.INB5423
#  ...          ...          ...             ...
#  1746      1996.0    34.985039  C.BOUC.INB5423
#  1747      1997.0    34.783319  C.BOUC.INB5423
#  1748      1998.0    34.685185  C.BOUC.INB5423
#  1749      1999.0    34.867191  C.BOUC.INB5423
#  1750      2000.0    35.068522  C.BOUC.INB5423
#
#  [1746 rows x 3 columns]]

# %%
create_folder_if_not_exists(report_location)
counterA = 1
counterB = 0
with matplotlib.backends.backend_pdf.PdfPages(report_location + "\\" + 'optical info.pdf') as pdf:
    counterB = 0
    
    for dataframe in absorptance_dataframes:
        #print(dataframe)
        counterB = counterB +1
        avg_plot = dataframe.plot(x='wavelength', y='absorptance', kind='scatter', s=markersize, title = f"Figure {counterA}.{counterB} " + (dataframe["code"].iloc[0]) + " ", figsize = (8, 6), grid= True)
        avg_plot.set_xlabel("Wavelength [nm] ")
        avg_plot.set_ylabel("absorptance [%]")
        #save figures
        pdf.savefig()
        #close plot
        plt.close()
    
    counterA = 2
    counterB = 0
    
    for dataframe in transmittance_dataframes:
        counterB = counterB +1
        #print(dataframe["code"])
        #print(dataframe.file)
        avg_plot = dataframe.plot(x='wavelength', y='transmittance', kind='scatter', s=markersize, title = f"Figure {counterA}.{counterB} " + (dataframe["code"].iloc[0]) + " ", figsize = (8, 6), grid= True)
        avg_plot.set_xlabel("Wavelength [nm] ")
        avg_plot.set_ylabel("transmittance [%]")
        #save figures
        pdf.savefig()
        #close plot
        plt.close()
    
    counterA = 3
    counterB = 0
    
    for dataframe in reflectance_dataframes:
        counterB = counterB +1
        #print(dataframe.file)
        avg_plot = dataframe.plot(x='wavelength', y='reflectance', kind='scatter', s=markersize, title = f"Figure {counterA}.{counterB} " + (dataframe["code"].iloc[0]) + " ", figsize = (8, 6), grid= True)
        avg_plot.set_xlabel("Wavelength [nm] ")
        avg_plot.set_ylabel("reflectance [%]")
        #save figures
        pdf.savefig()
        #close plot
        plt.close()
        
    counterA = 4
    counterB = 0
    
    for dataframe in transflectance_dataframes:
        counterB = counterB +1
        #print(dataframe.file)
        avg_plot = dataframe.plot(x='wavelength', y='transflectance', kind='scatter', s=markersize, title = f"Figure {counterA}.{counterB} " + (dataframe["code"].iloc[0]) + " ", figsize = (8, 6), grid= True)
        avg_plot.set_xlabel("Wavelength [nm] ")
        avg_plot.set_ylabel("transflectance [%]")
        #save figures
        pdf.savefig()
        #close plot
        plt.close()
# Out:
# Folder 'E:\CICIMA\OneDrive_2024-03-14\Estudio Optico Escarabajos\report' already exists.
