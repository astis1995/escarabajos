# %% [markdown]
# # Batch Spectroscopy File Parsing Script

# %% [markdown]
# ### Author: Vinicio Soto, CICIMA
# ### This script works with raw Lambdas1050's ASC files in batch. It corrects Lambdas1050's detector jump between 857 nm and 858 nm and performs a Savitzky-Golay filtering on the corrected data
#
# #### exclusion_list.txt: You can add a file with this name to the folder with the data to exclude any file with that name
#
# This script reads every l1050 file in folder and its subfolders and create a unique average, jump_corrected_files, report and std_dev folders
# It creates sections for each folder with its information

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd #Data analysis
import numpy as np  #Array and numeric methods
from matplotlib.backends.backend_pdf import PdfPages #pri*nt PDFS
import matplotlib #pri*nt graphs
import matplotlib.pyplot as plt #pri*nt graphs
import os #operating system
import re #regular expression manipulation
from datetime import datetime #date and time methods
import logging #to log errors

#import spectraltools
#This script requires the file spectraltools.py to work
import sys
# Add the external folder to the system path
current_dir = os.getcwd()
external_folder_path = os.path.abspath(os.path.join(current_dir, '../libraries'))
sys.path.append(external_folder_path)

#This line of code allow us to access data in colab
#functionality to reload modules

import importlib
import spectraltools
import metrics
import datapath_selector

# clear the import cache
importlib.reload(metrics)
importlib.reload(spectraltools)
importlib.reload(datapath_selector)
# now you can import my_class and it'll be updated
from metrics import *
from spectraltools import *
from datapath_selector import get_paths
from pathlib import Path
# Out:
# C:\Users\esteb\cicima\escarabajos\libraries\spectraltools.py:36: SyntaxWarning: invalid escape sequence '\d'
#   "craic_filename_regex_6" : "(\d+)(?:(escutelo)*(pronoto)*)([RLOT])(\d+)",
# C:\Users\esteb\cicima\escarabajos\libraries\spectraltools.py:37: SyntaxWarning: invalid escape sequence '\d'
#   "macraspis-blue-1": "(\d+)-macraspis-blue-average([TOLR]).csv", #reading pol
# C:\Users\esteb\cicima\escarabajos\libraries\spectraltools.py:38: SyntaxWarning: invalid escape sequence '\d'
#   "sinnumero-rojo": "sinnumero-rojo-(\d+)", #reading
# C:\Users\esteb\cicima\escarabajos\libraries\spectraltools.py:39: SyntaxWarning: invalid escape sequence '\d'
#   "macraspis-green": "(\d+)-macraspis-green-average([LRTO]).csv", #reading polarization,

# %% [markdown]
# ### Instructions:
#
# Write your archive folders' path in file_folder_data_path list

# %%
#parent folder path
date = str(datetime.today().date())

#file_folder_data_path =[ #r"C:\Users\EstebanSoto\Jupyter\escarabajos\L1050_data\CICIMA-2024-05-REFLECTANCE\DORSAL",
                         #r"C:\Users\EstebanSoto\Jupyter\escarabajos\L1050_data\CICIMA-2024-05-REFLECTANCE\VENTRAL",
                         #r"C:\Users\EstebanSoto\Jupyter\escarabajos\L1050_data\CICIMA-2024-03-REFLECTANCE\without iris nor lens",
                         #r"C:\Users\EstebanSoto\Jupyter\escarabajos\L1050_data\2024-04-INBUCR-REFLECTANCE",
                         #r"C:\Users\EstebanSoto\Jupyter\escarabajos\L1050_data\2023-03-CICIMAUCR-2-REFLECTANCE",
                         #r"C:\Users\esteb\cicima\escarabajos\L1050_data\CICIMA-2024-05-REFLECTANCE\DORSAL"
                       #]
parent_folder_data_path = Path(r"C:\Users\esteb\cicima\escarabajos\test\data\test_step_jump_correction\files") 

#create a subfolder called report with the correction process info  
report_path = ((parent_folder_data_path.parent / "reports" )/ f"{date}") / (parent_folder_data_path.name)
#pri*nt(report_path)
report_path.mkdir(parents=True, exist_ok=True)

#create a subfolder called corrected_files
corrected_files_path = ((parent_folder_data_path.parent / f"corrected_files_{date}" )/ f"{date}") / parent_folder_data_path.name
#pri*nt(corrected_files_path)
corrected_files_path.mkdir(parents=True, exist_ok=True)

#create a subfolder called average and std

average_files_path = ((parent_folder_data_path.parent / f"average" )/ f"{date}") / parent_folder_data_path.name
#pri*nt(average_files_path)
average_files_path.mkdir(parents=True, exist_ok=True)

std_files_path = ((parent_folder_data_path.parent / f"std" )/ f"{date}") / parent_folder_data_path.name
#pri*nt(std_files_path)
std_files_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# #### Collections

# %%
"""OPTIONS: cicima_laptop, colaboratory, wfh, cicima_desktop
    """
collection_paths = get_paths()
#pri*nt(collection_paths)

inbio_2018_2019_collection = Specimen_Collection("INBIO", collection_paths["2018_2019_inbio_collection_path"] , collection_paths["2018_2019_inbio_collection_metadata"] , "HIGH")
angsol_collection = Specimen_Collection("ANGSOL", collection_paths["angsol_collection_path"] , collection_paths["angsol_collection_metadata"] , "HIGH")
angsol_collection.set_description("ANGSOL collection has specimens that belong to Angel Solís. The confidence that we have about specimen identification is high.")

cicimaucr_collection = Specimen_Collection("CICIMAUCR1", collection_paths["cicimaucr_collection_path"] , collection_paths["cicima_ucr_metadata"] , "HIGH")
cicimaucr_collection_2 = Specimen_Collection("CICIMAUCR2", collection_paths["cicimaucr_collection_2_path"] , collection_paths["cicima_ucr_metadata"] , "HIGH")
cicimaucr_collection_3 = Specimen_Collection("CICIMAUCR3", collection_paths["cicimaucr_collection_3_path"] , collection_paths["cicima_ucr_metadata"] , "HIGH")
inbucr_collection = Specimen_Collection("INBUCR", collection_paths["inbucr_collection_path"] , collection_paths["inbucr_metadata"] , "HIGH")
bioucr_collection = Specimen_Collection("BIOUCR", collection_paths["bioucr_collection_path"] , collection_paths["bioucr_metadata"] , "LOW")

collection_list = [
                    inbio_2018_2019_collection,
                    angsol_collection,
                    cicimaucr_collection,
                    cicimaucr_collection_2,
                    cicimaucr_collection_3,
                    inbucr_collection,
                    bioucr_collection,
                    ]
codes_in_collection = []
for collection in collection_list:
    codes_in_collection += collection.get_codes()
print(codes_in_collection)
# Out:
# ['1037312', '2467329', '4294666', '1054219', '1787923', '2596378', '4146715', '667677', '2422833', '2422834', '2452030', '2453057', '2388550', '2388554', '2375764', '2202197', '2375765', '2375766', '2208353', '3731054', '714869', '856696', '2214015', '3710592', '801925', '20181128', '4090505', '1728138', '4090508', '3169943', '2376856', '112793', '2376857', '2371249', '532145', '532146', '1309367', '714947', '3102408', '3014858', '3102412', '159438', '4249297', '3014866', '3014867', '2565845', '3720411', '3165406', '3165411', '4224244', '3302646', '4224249', '3085577', '1736458', '1736459', '353553', '3708178', '1922846', '2249504', '2249505', '2363681', '2604835', '419121', '2417991', '2417992', '2417993', '2417994', '2417995', '2417998', '1717599', '1717600', '2248544', '1147235', '1717606', '1207144', '2181994', '2234738', '776563', '2516851', '987517', '360323', '2448774', '602505', '2375565', '1670038', '3036568', '2195354', '2195355', '2195357', '2195358', '1397155', '592808', '4298666', '209836', '2398124', '2415026', '2548659', '3045302', '3359158', '2456006', '668621', '3550669', '2210262', '3977178', '3353565', '121321', '1037298', '1037299', '623604', '2253302', '2361339', '1037308', 'ANGSOL0032', 'ANGSOL0013', 'ANGSOL0031', 'ANGSOL0024', 'ANGSOL0034', 'ANGSOL0010', 'ANGSOL0021', 'ANGSOL0009', 'ANGSOL0027', 'ANGSOL0004', 'ANGSOL0005', 'ANGSOL0006', 'ANGSOL0003', 'ANGSOL0025', 'ANGSOL0035', 'ANGSOL0030', 'ANGSOL0018', 'ANGSOL0028', 'ANGSOL0014', 'ANGSOL0002', 'ANGSOL0015', 'ANGSOL0008', 'ANGSOL0016', 'ANGSOL0023', 'ANGSOL0026', 'ANGSOL0012', 'ANGSOL0017', 'ANGSOL0033', 'ANGSOL0007', 'ANGSOL0011', 'ANGSOL0029', 'ANGSOL0001', 'ANGSOL0022', 'ANGSOL0019', 'ANGSOL0020', 'CICIMAUCR0039', 'CICIMAUCR0107', 'CICIMAUCR0221', 'CICIMAUCR0046', 'CICIMAUCR0041', 'CICIMAUCR0168', 'CICIMAUCR0104', 'CICIMAUCR0226', 'CICIMAUCR0062', 'CICIMAUCR0232', 'CICIMAUCR0164', 'CICIMAUCR0207', 'CICIMAUCR0070', 'CICIMAUCR0142', 'CICIMAUCR0053', 'CICIMAUCR0058', 'CICIMAUCR0162', 'CICIMAUCR0101', 'CICIMAUCR0090', 'CICIMAUCR0050', 'CICIMAUCR0029', 'CICIMAUCR0251', 'CICIMAUCR0064', 'CICIMAUCR0083', 'CICIMAUCR0092', 'CICIMAUCR0145', 'CICIMAUCR0035', 'CICIMAUCR0209', 'CICIMAUCR0099', 'CICIMAUCR0177', 'CICIMAUCR0151', 'CICIMAUCR0001', 'CICIMAUCR0047', 'CICIMAUCR0043', 'CICIMAUCR0094', 'CICIMAUCR0097', 'CICIMAUCR0180', 'CICIMAUCR0106', 'CICIMAUCR0093', 'CICIMAUCR0171', 'CICIMAUCR0108', 'CICIMAUCR0179', 'CICIMAUCR0249', 'CICIMAUCR0250', 'CICIMAUCR0166', 'CICIMAUCR0022', 'CICIMAUCR0241', 'CICIMAUCR0233', 'CICIMAUCR0205', 'CICIMAUCR0076', 'CICIMAUCR0079', 'CICIMAUCR0181', 'CICIMAUCR0159', 'CICIMAUCR0060', 'CICIMAUCR0010', 'CICIMAUCR0259', 'CICIMAUCR0124', 'CICIMAUCR0146', 'CICIMAUCR0066', 'CICIMAUCR0056', 'CICIMAUCR0148', 'CICIMAUCR0156', 'CICIMAUCR0034', 'CICIMAUCR0082', 'CICIMAUCR0073', 'CICIMAUCR0080', 'CICIMAUCR0012', 'CICIMAUCR0110', 'CICIMAUCR0098', 'CICIMAUCR0236', 'CICIMAUCR0014', 'CICIMAUCR0161', 'CICIMAUCR0132', 'CICIMAUCR0167', 'CICIMAUCR0237', 'CICIMAUCR0023', 'CICIMAUCR0214', 'CICIMAUCR0048', 'CICIMAUCR0077', 'CICIMAUCR0139', 'CICIMAUCR0150', 'CICIMAUCR0235', 'CICIMAUCR0141', 'CICIMAUCR0128', 'CICIMAUCR0065', 'CICIMAUCR0155', 'CICIMAUCR0009', 'CICIMAUCR0087', 'CICIMAUCR0121', 'CICIMAUCR0216', 'CICIMAUCR0037', 'CICIMAUCR0016', 'CICIMAUCR0085', 'CICIMAUCR0135', 'CICIMAUCR0013', 'CICIMAUCR0018', 'CICIMAUCR0015', 'CICIMAUCR0169', 'CICIMAUCR0020', 'CICIMAUCR0125', 'CICIMAUCR0084', 'CICIMAUCR0206', 'CICIMAUCR0133', 'CICIMAUCR0033', 'CICIMAUCR0069', 'CICIMAUCR0081', 'CICIMAUCR0052', 'CICIMAUCR0086', 'CICIMAUCR0118', 'CICIMAUCR0130', 'CICIMAUCR0051', 'CICIMAUCR0027', 'CICIMAUCR0054', 'CICIMAUCR0208', 'CICIMAUCR0143', 'CICIMAUCR0234', 'CICIMAUCR0170', 'CICIMAUCR0126', 'CICIMAUCR0222', 'CICIMAUCR0123', 'CICIMAUCR0175', 'CICIMAUCR0095', 'CICIMAUCR0116', 'CICIMAUCR0102', 'CICIMAUCR0173', 'CICIMAUCR0228', 'CICIMAUCR0158', 'CICIMAUCR0129', 'CICIMAUCR0210', 'CICIMAUCR0127', 'CICIMAUCR0119', 'CICIMAUCR0005', 'CICIMAUCR0007', 'CICIMAUCR0032', 'CICIMAUCR0109', ' ...

# %% [markdown]
# ### Constants
# Define your constants

# %%
#determine 
markersize = 1
#date


correction_file_path = Path(r"..\test\data\test_step_jump_correction\corrections\aluminum_mirror_reflectance.txt")
correction_df = pd.read_csv(correction_file_path, sep="\t",decimal=",", names = ["wavelength","reflectance"], skiprows=1)
correction_df

def integer_generator(start=0):
    if(start%100==0):
        print(f"{start=}")
    while True:
        yield start
        start += 1
gen = integer_generator()

# %% [markdown]
# ### Functions

# %% [markdown]
# ### Correction process function

# %%
def jump_correction(Spectrum):
    """Receives a l1050 spectrum and corrects its detector jump"""
    metadata = Spectrum.get_metadata()
    df = Spectrum.get_dataframe()
    
    #measuring_mode
    measuring_mode = metadata["measuring_mode"]
    
    #convert columns to float
    df['wavelength'] = df['wavelength'].astype(float)
    df[measuring_mode] = df[measuring_mode].astype(float)
    

    #This code finds the rows before and after the detector change
    #freq1 is the frequency before the change and freq2 is the frequency after the change
    wavelenght1 = 857.000000 #857
    wavelenght2 = 858.000000 #858
    
    #pri*nt("Loc")
    row1 = df.loc[ df['wavelength'] == wavelenght1]
    row2 = df.loc[ df['wavelength'] == wavelenght2]
    row12 = df.loc[ df['wavelength'] == wavelenght1-1]
    row13 = df.loc[ df['wavelength'] == wavelenght1-2]
    row14 = df.loc[ df['wavelength'] == wavelenght1-3]
    row15 = df.loc[ df['wavelength'] == wavelenght1-4]
    
    #This code finds the values corresponding to those frequencies and creates a correction factor
    
    try:
        data1 = row1.iat[0,1]
        data2 = row2.iat[0,1]
        data22 = row12.iat[0,1]
        data23 = row13.iat[0,1]
        data24 = row14.iat[0,1]
        data25 = row15.iat[0,1]
    
        data1_avg = (data1 + data22+data23)/3 #+data24+data25)/5
        data2_avg = (data2)
        correction_factor= data1_avg/data2_avg  
    
        #Multiply all frequencies equal or greater than freq2 by correction_factor
        df2 = df
        df2.loc[df2["wavelength"] >= wavelenght2 , [measuring_mode]] *= correction_factor
        
        
        return df
    except Exception as e:
        
        #pri*nt(e)
        return pd.DataFrame([])

# %% [markdown]
# ### Define Savitzky-Golay Filter

# %%
from scipy.signal import savgol_filter

def savitzky_golay_filter(metadata, df) -> pd.DataFrame:
    """Defines a Savitzky Golay Filter: Basically, smooths out the function. https://es.wikipedia.org/wiki/Filtro_de_Savitzky%E2%80%93Golay"""
    measuring_mode = metadata["measuring_mode"]
    y = df[measuring_mode] = df[measuring_mode].astype(float)
    
    # Apply Savitzky-Golay filter
    window_length = 21  # Window length (odd number)
    polyorder = 2  # Polynomial order
    y_smooth = savgol_filter(y, window_length, polyorder)
    
    #create new dataframe
    df_smooth = pd.DataFrame([])
    df_smooth["wavelength"] =df["wavelength"]
    df_smooth[measuring_mode] = y_smooth
    
    return df_smooth

# %% [markdown]
# ### Define function that filters selected extensions

# %%
def list_all_filepaths(parent_folder):
    filepaths = []
    
    # Walk through the directory
    for root, dirs, files in os.walk(parent_folder):
        for file in files:
            # Combine the root directory with the file name to get the full path
            filepath = os.path.join(root, file)
            filepaths.append(filepath)
    
    return filepaths
file_list = list_all_filepaths(parent_folder_data_path)
#pri*nt(f"{file_list=}")

# %%
def get_exclusion_list(file_list):
        """Only files whose name is in the exclusion list"""
        #file extension
        file_extension = "exclusion_list"
    
        # filters a list of strings to create a new list containing only the elements that have exclusion_list"
    
        def filter_substring_elements(path_strings, substring):
            filtered_paths = [path for path in path_strings if substring in path]
            return filtered_paths
    
        # Filter elements
        filtered_list = filter_substring_elements(file_list, file_extension)
    
        # Displaying the filtered list
        #pri*nt(filtered_list)
        
        return filtered_list
exclusion_list = get_exclusion_list(file_list)
#pri*nt(f"{exclusion_list=}")

# %%
def filter_list_CRAIC_and_l1050(path_list):
    """Only l1050 files and CRAIC files are read"""
    filtered_list = []

    filtered_list += [path for path in path_list if (check_CRAIC_file(path) or check_l1050_file(path))]

    return filtered_list

filtered_list = filter_list_CRAIC_and_l1050(file_list)

#pri*nt(f"{filtered_list=}")

# %%
def filter_failed_runs(filtered_list):
    """Filter runs that failed"""
    #file extension
    fail_strings = ["fail"]

    # filters a list of strings to create a new list containing only the elements that end with ".ASC"

    def filter_substring_elements(path_strings, substring):
        filtered_paths = [path for path in path_strings if substring not in path]
        return filtered_paths

    # Filtering elements with any of the fail strings
    for string in fail_strings: 
        filtered_list = filter_substring_elements(filtered_list, string)

    # Displaying the filtered list
    #pri*nt(filtered_list)
    
    return filtered_list

successful_list = filter_failed_runs(filtered_list)
#pri*nt(f"{successful_list=}")

# %% [markdown]
# ### Logic: Remove jumps

# %%
# From this list we will make a set of codes.
#pri*nt(filenames)
 
codes = []
for path in successful_list:
    code = get_code_from_filename(path)
    if code: 
        codes.append(code)
codes = set(codes)
codes = sorted(codes)
codes = [code for code in codes if (code in codes_in_collection)] #only codes that are in a collection
#pri*nt(f"codes {codes}")
# Out:
# string_line='1037298L1.csv'
# format_type='craic_filename_regex_1'
# string_line='1037298L2.csv'
# format_type='craic_filename_regex_1'
# string_line='1037298L3.csv'
# format_type='craic_filename_regex_1'
# string_line='1037298R1.csv'
# format_type='craic_filename_regex_1'
# string_line='1037298R2.csv'
# format_type='craic_filename_regex_1'
# string_line='1037298R3.csv'
# format_type='craic_filename_regex_1'
# string_line='1037299L1.csv'
# format_type='craic_filename_regex_1'
# string_line='1037299L2.csv'
# format_type='craic_filename_regex_1'
# string_line='1037299L3.csv'
# format_type='craic_filename_regex_1'
# string_line='1037299R1.csv'
# format_type='craic_filename_regex_1'
# string_line='1037299R2.csv'
# format_type='craic_filename_regex_1'
# string_line='1037299R3.csv'
# format_type='craic_filename_regex_1'
# string_line='1037308L1.csv'
# format_type='craic_filename_regex_1'
# string_line='1037308L2.csv'
# format_type='craic_filename_regex_1'
# string_line='1037308L3.csv'
# format_type='craic_filename_regex_1'
# string_line='1037308R1.csv'
# format_type='craic_filename_regex_1'
# string_line='1037308R2.csv'
# format_type='craic_filename_regex_1'
# string_line='1037308R3.csv'
# format_type='craic_filename_regex_1'
# string_line='1037312L1.csv'
# format_type='craic_filename_regex_1'
# string_line='1037312L2.csv'
# format_type='craic_filename_regex_1'
# string_line='1037312L3.csv'
# format_type='craic_filename_regex_1'
# string_line='1037312R1.csv'
# format_type='craic_filename_regex_1'
# string_line='1054219L1.csv'
# format_type='craic_filename_regex_1'
# string_line='1054219L2.csv'
# format_type='craic_filename_regex_1'
# string_line='1054219L3.csv'
# format_type='craic_filename_regex_1'
# string_line='1054219R1.csv'
# format_type='craic_filename_regex_1'
# string_line='1054219R2.csv'
# format_type='craic_filename_regex_1'
# string_line='1054219R3.csv'
# format_type='craic_filename_regex_1'
# string_line='1309367L1.csv'
# format_type='craic_filename_regex_1'
# string_line='1309367L2.csv'
# format_type='craic_filename_regex_1'
# string_line='1309367L3.csv'
# format_type='craic_filename_regex_1'
# string_line='1309367R1.csv'
# format_type='craic_filename_regex_1'
# string_line='1309367R2.csv'
# format_type='craic_filename_regex_1'
# string_line='1309367R3.csv'
# format_type='craic_filename_regex_1'
# string_line='159438R1.csv'
# format_type='craic_filename_regex_1'
# string_line='159438R2.csv'
# format_type='craic_filename_regex_1'
# string_line='159438R3.csv'
# format_type='craic_filename_regex_1'
# string_line='1717606L1.csv'
# format_type='craic_filename_regex_1'
# string_line='1717606L2.csv'
# format_type='craic_filename_regex_1'
# string_line='1717606L3.csv'
# format_type='craic_filename_regex_1'
# string_line='1717606R1.csv'
# format_type='craic_filename_regex_1'
# string_line='1717606R2.csv'
# format_type='craic_filename_regex_1'
# string_line='1717606R3.csv'
# format_type='craic_filename_regex_1'
# string_line='1736458L1.csv'
# format_type='craic_filename_regex_1'
# string_line='1736458L2.csv'
# format_type='craic_filename_regex_1'
# string_line='1736458L3.csv'
# format_type='craic_filename_regex_1'
# string_line='1736458R1.csv'
# format_type='craic_filename_regex_1'
# string_line='1736458R2.csv'
# format_type='craic_filename_regex_1'
# string_line='1736458R3.csv'
# format_type='craic_filename_regex_1'
# string_line='1736459L1.csv'
# format_type='craic_filename_regex_1'
# string_line='1736459L2.csv'
# format_type='craic_filename_regex_1'
# string_line='1736459L3.csv'
# format_type='craic_filename_regex_1'
# string_line='1736459R1.csv'
# format_type='craic_filename_regex_1'
# string_line='1736459R2.csv'
# format_type='craic_filename_regex_1'
# string_line='1736459R3.csv'
# format_type='craic_filename_regex_1'
# string_line='209836L1.csv'
# format_type='craic_filename_regex_1'
# string_line='209836L2.csv'
# format_type='craic_filename_regex_1'
# string_line='209836L3.csv'
# format_type='craic_filename_regex_1'
# string_line='209836R1.csv'
# format_type='craic_filename_regex_1'
# string_line='209836R2.csv'
# format_type='craic_filename_regex_1'
# string_line='209836R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2181994L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2181994L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2181994L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2181994R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2181994R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2181994R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2195354L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2195354L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2195354L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2195354R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2195354R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2195354R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2195355L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2195355L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2195355L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2195355R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2195355R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2195355R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2195357L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2195357L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2195357L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2195357R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2195357R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2195357R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2195358L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2195358L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2195358L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2195358R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2195358R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2195358R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2234738L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2234738L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2234738L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2234738R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2234738R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2234738R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2248544L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2248544L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2248544L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2248544R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2248544R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2248544R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2249504L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2249504L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2249504L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2249504R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2249504R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2249504R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505L4.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505L5.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505R4.csv'
# format_type='craic_filename_regex_1'
# string_line='2249505R5.csv'
# format_type='craic_filename_regex_1'
# string_line='2253302L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2253302L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2253302L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2253302R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2253302R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2253302R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2361339L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2361339L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2361339R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2361339R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2375565L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2375565L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2375565L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2375565L4.csv'
# format_type='craic_filename_regex_1'
# string_line='2375565R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2375565R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2375565R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2375565R4.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856L4.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856L5.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856R4.csv'
# format_type='craic_filename_regex_1'
# string_line='2376856R5.csv'
# format_type='craic_filename_regex_1'
# string_line='2376857L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2376857L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2376857L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2376857L4.csv'
# format_type='craic_filename_regex_1'
# string_line='2376857R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2376857R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2376857R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2376857R4.csv'
# format_type='craic_filename_regex_1'
# string_line='2388550L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2388550L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2388550L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2388550L4.csv'
# format_type='craic_filename_regex_1'
# string_line='2388550R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2388550R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2388550R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2388550R4.csv'
# format_type='craic_filename_regex_1'
# string_line='2388554L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2388554L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2388554L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2388554R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2388554R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2388554R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2422833L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2422833L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2422833L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2422833R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2422833R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2422833R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2422834L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2422834L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2422834L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2422834R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2422834R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2422834R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2452030L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2452030L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2452030L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2452030L4.csv'
# format_type='craic_filename_regex_1'
# string_line='2452030R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2452030R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2452030R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2452030R4.csv'
# format_type='craic_filename_regex_1'
# string_line='2453057L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2453057L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2453057L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2453057L4.csv'
# format_type='craic_filename_regex_1'
# string_line='2453057R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2453057R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2453057R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2453057R4.csv'
# format_type='craic_filename_regex_1'
# string_line='2456006L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2456006L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2456006L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2456006R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2456006R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2456006R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2467329L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2467329L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2467329L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2467329L4.csv'
# format_type='craic_filename_regex_1'
# string_line='2467329R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2467329R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2467329R3.csv'
# format_type='craic_filename_regex_1'
# string_line='2467329R4.csv'
# format_type='craic_filename_regex_1'
# string_line='2548659L1.csv'
# format_type='craic_filename_regex_1'
# string_line='2548659L2.csv'
# format_type='craic_filename_regex_1'
# string_line='2548659L3.csv'
# format_type='craic_filename_regex_1'
# string_line='2548659R1.csv'
# format_type='craic_filename_regex_1'
# string_line='2548659R2.csv'
# format_type='craic_filename_regex_1'
# string_line='2548659R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3036568L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3036568L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3036568L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3036568R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3036568R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3036568R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3045302L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3045302L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3045302L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3045302R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3045302R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3045302R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3102408L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3102408L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3102408L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3102408R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3102408R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3102408R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3102412L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3102412L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3102412L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3102412R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3102412R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3102412R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3165406L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3165406L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3165406L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3165406R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3165406R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3165406R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3165411L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3165411L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3165411L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3165411R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3165411R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3165411R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3169943L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3169943L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3169943L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3169943R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3169943R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3169943R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3353565L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3353565L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3353565L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3353565R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3353565R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3353565R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3359158L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3359158L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3359158L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3359158R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3359158R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3359158R3.csv'
# format_type='craic_filename_regex_1'
# string_line='353553L1.csv'
# format_type='craic_filename_regex_1'
# string_line='353553L2.csv'
# format_type='craic_filename_regex_1'
# string_line='353553L3.csv'
# format_type='craic_filename_regex_1'
# string_line='353553R1.csv'
# format_type='craic_filename_regex_1'
# string_line='353553R2.csv'
# format_type='craic_filename_regex_1'
# string_line='353553R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3708178L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3708178L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3708178L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3708178R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3708178R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3708178R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3710592L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3710592L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3710592L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3710592R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3710592R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3710592R3.csv'
# format_type='craic_filename_regex_1'
# string_line='3720411L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3720411L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3720411R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3720411R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3720411R3.csv'
# format_type='craic_filename_regex_1'
# string_line='372411L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3731054L1.csv'
# format_type='craic_filename_regex_1'
# string_line='3731054L2.csv'
# format_type='craic_filename_regex_1'
# string_line='3731054L3.csv'
# format_type='craic_filename_regex_1'
# string_line='3731054R1.csv'
# format_type='craic_filename_regex_1'
# string_line='3731054R2.csv'
# format_type='craic_filename_regex_1'
# string_line='3731054R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4090505L1.csv'
# format_type='craic_filename_regex_1'
# string_line='4090505L2.csv'
# format_type='craic_filename_regex_1'
# string_line='4090505L3.csv'
# format_type='craic_filename_regex_1'
# string_line='4090505R1.csv'
# format_type='craic_filename_regex_1'
# string_line='4090505R2.csv'
# format_type='craic_filename_regex_1'
# string_line='4090505R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4090508L1.csv'
# format_type='craic_filename_regex_1'
# string_line='4090508L2.csv'
# format_type='craic_filename_regex_1'
# string_line='4090508L3.csv'
# format_type='craic_filename_regex_1'
# string_line='4090508R1.csv'
# format_type='craic_filename_regex_1'
# string_line='4090508R2.csv'
# format_type='craic_filename_regex_1'
# string_line='4090508R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4146715L1.csv'
# format_type='craic_filename_regex_1'
# string_line='4146715L2.csv'
# format_type='craic_filename_regex_1'
# string_line='4146715L3.csv'
# format_type='craic_filename_regex_1'
# string_line='4146715L4.csv'
# format_type='craic_filename_regex_1'
# string_line='4146715R1.csv'
# format_type='craic_filename_regex_1'
# string_line='4146715R2.csv'
# format_type='craic_filename_regex_1'
# string_line='4146715R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4146715R4.csv'
# format_type='craic_filename_regex_1'
# string_line='419121L1.csv'
# format_type='craic_filename_regex_1'
# string_line='419121L2.csv'
# format_type='craic_filename_regex_1'
# string_line='419121L3.csv'
# format_type='craic_filename_regex_1'
# string_line='419121R1.csv'
# format_type='craic_filename_regex_1'
# string_line='419121R2.csv'
# format_type='craic_filename_regex_1'
# string_line='419121R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4224244L1.csv'
# format_type='craic_filename_regex_1'
# string_line='4224244L3.csv'
# format_type='craic_filename_regex_1'
# string_line='4224244R1.csv'
# format_type='craic_filename_regex_1'
# string_line='4224244R2.csv'
# format_type='craic_filename_regex_1'
# string_line='4224244R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4224249L1.csv'
# format_type='craic_filename_regex_1'
# string_line='4224249L2.csv'
# format_type='craic_filename_regex_1'
# string_line='4224249L3.csv'
# format_type='craic_filename_regex_1'
# string_line='4224249R1.csv'
# format_type='craic_filename_regex_1'
# string_line='4224249R2.csv'
# format_type='craic_filename_regex_1'
# string_line='4224249R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4249297L1.csv'
# format_type='craic_filename_regex_1'
# string_line='4249297L2.csv'
# format_type='craic_filename_regex_1'
# string_line='4249297L3.csv'
# format_type='craic_filename_regex_1'
# string_line='4249297R1.csv'
# format_type='craic_filename_regex_1'
# string_line='4249297R2.csv'
# format_type='craic_filename_regex_1'
# string_line='4249297R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4294666L1.csv'
# format_type='craic_filename_regex_1'
# string_line='4294666L3.csv'
# format_type='craic_filename_regex_1'
# string_line='4294666R2.csv'
# format_type='craic_filename_regex_1'
# string_line='4294666R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4298666L1.csv'
# format_type='craic_filename_regex_1'
# string_line='4298666L2.csv'
# format_type='craic_filename_regex_1'
# string_line='4298666L3.csv'
# format_type='craic_filename_regex_1'
# string_line='4298666L4.csv'
# format_type='craic_filename_regex_1'
# string_line='4298666R1.csv'
# format_type='craic_filename_regex_1'
# string_line='4298666R2.csv'
# format_type='craic_filename_regex_1'
# string_line='4298666R3.csv'
# format_type='craic_filename_regex_1'
# string_line='4298666R4.csv'
# format_type='craic_filename_regex_1'
# string_line='532145L1.csv'
# format_type='craic_filename_regex_1'
# string_line='532145L2.csv'
# format_type='craic_filename_regex_1'
# string_line='532145L3.csv'
# format_type='craic_filename_regex_1'
# string_line='532145R1.csv'
# format_type='craic_filename_regex_1'
# string_line='532145R2.csv'
# format_type='craic_filename_regex_1'
# string_line='532145R3.csv'
# format_type='craic_filename_regex_1'
# string_line='532146L1.csv'
# format_type='craic_filename_regex_1'
# string_line='532146L2.csv'
# format_type='craic_filename_regex_1'
# string_line='532146L3.csv'
# format_type='craic_filename_regex_1'
# string_line='532146R1.csv'
# format_type='craic_filename_regex_1'
# string_line='532146R2.csv'
# format_type='craic_filename_regex_1'
# string_line='532146R3.csv'
# format_type='craic_filename_regex_1'
# string_line='623604L1.csv'
# format_type='craic_filename_regex_1'
# string_line='623604L2.csv'
# format_type='craic_filename_regex_1'
# string_line='623604L3.csv'
# format_type='craic_filename_regex_1'
# string_line='623604R1.csv'
# format_type='craic_filename_regex_1'
# string_line='623604R2.csv'
# format_type='craic_filename_regex_1'
# string_line='623604R3.csv'
# format_type='craic_filename_regex_1'
# string_line='668621L1.csv'
# format_type='craic_filename_regex_1'
# string_line='668621L2.csv'
# format_type='craic_filename_regex_1'
# string_line='668621L3.csv'
# format_type='craic_filename_regex_1'
# string_line='668621R1.csv'
# format_type='craic_filename_regex_1'
# string_line='668621R2.csv'
# format_type='craic_filename_regex_1'
# string_line='668621R3.csv'
# format_type='craic_filename_regex_1'
# string_line='714869L1.csv'
# format_type='craic_filename_regex_1'
# string_line='714869L2.csv'
# format_type='craic_filename_regex_1'
# string_line='714869L3.csv'
# format_type='craic_filename_regex_1'
# string_line='714869R1.csv'
# format_type='craic_filename_regex_1'
# string_line='714869R2.csv'
# format_type='craic_filename_regex_1'
# string_line='714869R3.csv'
# format_type='craic_filename_regex_1'
# string_line='714947L1.csv'
# format_type='craic_filename_regex_1'
# string_line='714947L2.csv'
# format_type='craic_filename_regex_1'
# string_line='714947L3.csv'
# format_type='craic_filename_regex_1'
# string_line='714947R1.csv'
# format_type='craic_filename_regex_1'
# string_line='714947R2.csv'
# format_type='craic_filename_regex_1'
# string_line='714947R3.csv'
# format_type='craic_filename_regex_1'
# string_line='776563L1.csv'
# format_type='craic_filename_regex_1'
# string_line='776563L2.csv'
# format_type='craic_filename_regex_1'
# string_line='776563L3.csv'
# format_type='craic_filename_regex_1'
# string_line='776563R1.csv'
# format_type='craic_filename_regex_1'
# string_line='776563R2.csv'
# format_type='craic_filename_regex_1'
# string_line='776563R3.csv'
# format_type='craic_filename_regex_1'
# string_line='856696L1.csv'
# format_type='craic_filename_regex_1'
# string_line='856696L2.csv'
# format_type='craic_filename_regex_1'
# string_line='856696L3.csv'
# format_type='craic_filename_regex_1'
# string_line='856696R1.csv'
# format_type='craic_filename_regex_1'
# string_line='856696R2.csv'
# format_type='craic_filename_regex_1'
# string_line='856696R3.csv'
# format_type='craic_filename_regex_1'
# string_line='987517L1.csv'
# format_type='craic_filename_regex_1'
# string_line='987517L2.csv'
# format_type='craic_filename_regex_1'
# string_line='987517L3.csv'
# format_type='craic_filename_regex_1'
# string_line='987517R1.csv'
# format_type='craic_filename_regex_1'
# string_line='987517R2.csv'
# format_type='craic_filename_regex_1'
# string_line='987517R3.csv'
# format_type='craic_filename_regex_1'
# string_line='test_l1050_spectrum_delete on 2025.ASC'
# format_type='l1050_filename_regex'
# string_line='1037298-1.csv'
# format_type='craic_filename_regex_3'
# string_line='1037298-2.csv'
# format_type='craic_filename_regex_3'
# string_line='1037298-3.csv'
# format_type='craic_filename_regex_3'
# string_line='1037299-1.csv'
# format_type='craic_filename_regex_3'
# string_line='1037299-2.csv'
# format_type='craic_filename_regex_3'
# string_line='1037299-3.csv'
# format_type='craic_filename_regex_3'
# string_line='1054219-1.csv'
# format_type='craic_filename_regex_3'
# string_line='1054219-2.csv'
# format_type='craic_filename_regex_3'
# string_line='1054219-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2248544-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2248544-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2248544-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2249505-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2249505-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2249505-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2253302-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2253302-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2253302-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2361339-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2361339-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2361339-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2375565-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2375565-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2375565-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2376856-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2376856-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2376856-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2376857-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2376857-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2376857-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2388554-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2388554-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2388554-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2422833-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2422833-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2422833-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2422834-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2422834-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2422834-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2452030-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2452030-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2452030-3.csv'
# format_type='craic_filename_regex_3'
# string_line='388550-1.csv'
# format_type='craic_filename_regex_3'
# string_line='388550-2.csv'
# format_type='craic_filename_regex_3'
# string_line='388550-3.csv'
# format_type='craic_filename_regex_3'
# string_line='4146715-1.csv'
# format_type='craic_filename_regex_3'
# string_line='4146715-2.csv'
# format_type='craic_filename_regex_3'
# string_line='4146715-3.csv'
# format_type='craic_filename_regex_3'
# string_line='4298666-1.csv'
# format_type='craic_filename_regex_3'
# string_line='4298666-2.csv'
# format_type='craic_filename_regex_3'
# string_line='4298666-3.csv'
# format_type='craic_filename_regex_3'
# string_line='453057-1.csv'
# format_type='craic_filename_regex_3'
# string_line='453057-2.csv'
# format_type='craic_filename_regex_3'
# string_line='453057-3.csv'
# format_type='craic_filename_regex_3'
# string_line='467329-1.csv'
# format_type='craic_filename_regex_3'
# string_line='467329-2.csv'
# format_type='craic_filename_regex_3'
# string_line='467329-3.csv'
# format_type='craic_filename_regex_3'
# string_line='532145-1.csv'
# format_type='craic_filename_regex_3'
# string_line='532145-2.csv'
# format_type='craic_filename_regex_3'
# string_line='532145-3.csv'
# format_type='craic_filename_regex_3'
# string_line='532146-1.csv'
# format_type='craic_filename_regex_3'
# string_line='532146-2.csv'
# format_type='craic_filename_regex_3'
# string_line='532146-3.csv'
# format_type='craic_filename_regex_3'
# string_line='refscan.csv'
# format_type=None
# string_line='1309364-1.csv'
# format_type='craic_filename_regex_3'
# string_line='1309364-2.csv'
# format_type='craic_filename_regex_3'
# string_line='1309364-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2142454-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2142454-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2142454-3.csv'
# format_type='craic_filename_regex_3'
# string_line='2248543-1.csv'
# format_type='craic_filename_regex_3'
# string_line='2248543-2.csv'
# format_type='craic_filename_regex_3'
# string_line='2248543-3.csv'
# format_type='craic_filename_regex_3'
# string_line='3359158-1.csv'
# format_type='craic_filename_regex_3'
# string_line='3359158-2.csv'
# format_type='craic_filename_regex_3'
# string_line='3359158-3.csv'
# format_type='craic_filename_regex_3'
# string_line='338580-1.csv'
# format_type='craic_filename_regex_3'
# string_line='338580-2.csv'
# format_type='craic_filename_regex_3'
# string_line='338580-3.csv'
# format_type='craic_filename_regex_3'
# string_line='3708178-1.csv'
# format_type='craic_filename_regex_3'
# string_line='3708178-2.csv'
# format_type='craic_filename_regex_3'
# string_line='3708178-3.csv'
# format_type='craic_filename_regex_3'
# string_line='3710592-1.csv'
# format_type='craic_filename_regex_3'
# string_line='3710592-2.csv'
# format_type='craic_filename_regex_3'
# string_line='3710592-3.csv'
# format_type='craic_filename_regex_3'
# string_line='3729411-1.csv'
# format_type='craic_filename_regex_3'
# string_line='3729411-2.csv'
# format_type='craic_filename_regex_3'
# string_line='3729411-3.csv'
# format_type='craic_filename_regex_3'
# string_line='3731054-01.csv'
# format_type='craic_filename_regex_3'
# string_line='3731054-2.csv'
# format_type='craic_filename_regex_3'
# string_line='3731054-3.csv'
# format_type='craic_filename_regex_3'
# string_line='404421-1.csv'
# format_type='craic_filename_regex_3'
# string_line='404421-2.csv'
# format_type='craic_filename_regex_3'
# string_line='404421-3.csv'
# format_type='craic_filename_regex_3'
# string_line='4090505-1.csv'
# format_type='craic_filename_regex_3'
# string_line='4090505-2.csv'
# format_type='craic_filename_regex_3'
# string_line='4090505-3.csv'
# format_type='craic_filename_regex_3'
# string_line='515691-1.csv'
# format_type='craic_filename_regex_3'
# string_line='515691-2.csv'
# format_type='craic_filename_regex_3'
# string_line='515691-3.csv'
# format_type='craic_filename_regex_3'
# string_line='515871-1.csv'
# format_type='craic_filename_regex_3'
# string_line='515871-2.csv'
# format_type='craic_filename_regex_3'
# string_line='515871-3.csv'
# format_type='craic_filename_regex_3'
# string_line='632557-1.csv'
# format_type='craic_filename_regex_3'
# string_line='632557-2.csv'
# format_type='craic_filename_regex_3'
# string_line='632557-3.csv'
# format_type='craic_filename_regex_3'
# string_line='676328-1.csv'
# format_type='craic_filename_regex_3'
# string_line='676328-2.csv'
# format_type='craic_filename_regex_3'
# string_line='676328-3.csv'
# format_type='craic_filename_regex_3'
# string_line='700646-1.csv'
# format_type='craic_filename_regex_3'
# string_line='700646-2.csv'
# format_type='craic_filename_regex_3'
# string_line='700646-3.csv'
# format_type='craic_filename_regex_3'
# string_line='701734-1.csv'
# format_type='craic_filename_regex_3'
# string_line='701734-2.csv'
# format_type='craic_filename_regex_3'
# string_line='701734-3.csv'
# format_type='craic_filename_regex_3'
# string_line='709171-1.csv'
# format_type='craic_filename_regex_3'
# string_line='709171-2.csv'
# format_type='craic_filename_regex_3'
# string_line='709171-3.csv'
# format_type='craic_filename_regex_3'
# string_line='858698-1.csv'
# format_type='craic_filename_regex_3'
# string_line='858698-2.csv'
# format_type='craic_filename_regex_3'
# string_line='858698-3.csv'
# format_type='craic_filename_regex_3'
# string_line='858699-1.csv'
# format_type='craic_filename_regex_3'
# string_line='858699-2.csv'
# format_type='craic_filename_regex_3'
# string_line='858699-3.csv'
# format_type='craic_filename_regex_3'
# string_line='refscan.csv'
# format_type=None

# %%
#for each file in the exclusion list
exclusion_list_df = pd.DataFrame()
for file in exclusion_list:
    df = pd.read_csv(file, header = 0, names=["filename", "reason"], delimiter = "\t")
    exclusion_list_df = pd.concat([exclusion_list_df, df], ignore_index = True)
#pri*nt(exclusion_list_df)
#pri*nt(f"{exclusion_list_df=}")

# %%
#remove excluded files
def remove_excluded_files(successful_list, exclusion_list_df):
    filtered_list = []

    #if the file is not empty it gets all files that are not in that list
    if not exclusion_list_df.empty:
        #gets a exclusion list
        exclusion_list = exclusion_list_df["filename"].values
        for excluded_file in exclusion_list:
                    filtered_list = [filename for filename in successful_list if excluded_file not in filename ]
    filtered_list = successful_list
    return filtered_list
    
successful_list_without_excluded_files = remove_excluded_files(successful_list, exclusion_list_df)
#pri*nt(f"{successful_list_without_excluded_files=}")

# %%
def remove_empty_files(successful_list_without_excluded_files):
    non_empty_files = [filename for filename in successful_list_without_excluded_files if ((not check_empty_CRAIC_file(filename)) and (not check_empty_l1050_file(filename)))]
    return non_empty_files

non_empty_files = remove_empty_files(successful_list_without_excluded_files)
#non_empty_files

# %%
def save_corrected_plot(folder, basename, metadata, dataframe, label = None):
    """
    Saves the dataframe into a file
    Inputs: A dataframe, the filename of the file from which the dataframe comes from and its metadata
    Output: None
    
    """
    
    plt.plot(dataframe["wavelength"], dataframe[metadata["measuring_mode"]], label = label, color= get_contrasting_color())

# %%
def save_corrected_df(folder, basename, metadata, dataframe):
    """
    Saves the dataframe into a file
    Inputs: A dataframe, the filename of the file from which the dataframe comes from and its metadata
    Output: None
    
    """
    #get only wavelength and metadata["measuring_mode"]
    dataframe = dataframe[["wavelength", metadata["measuring_mode"]]]
    #variables
    header = metadata["header"]
    
    #convert dataframe to numpy
    my_numpy_df_data = dataframe.to_numpy()

    #create folder
    if not os.path.exists(folder):
        os.mkdir(folder)

    #saves file, removes .ASC and removes .SAMPLE
    unnecessary_text = [".Sample", ".Cycle1"]
    replace_text = basename
    
    for text in unnecessary_text:
        #pri*nt(temp_text)
        replace_text = replace_text.replace(text, "")

    #new_archive_name
    new_archive_name = folder / replace_text

    #saves info
    with open(new_archive_name, 'wb') as f:
        np.savetxt(new_archive_name, my_numpy_df_data,fmt = "%.6f", delimiter="\t", header=header, comments='', )
    with open(new_archive_name, "r") as f:
        data = f.read()
    with open(new_archive_name, "w") as f:
        f.write(data.replace("#DATA\n","#DATA"))

# %%
def save_corrected_CRAIC_spectrum(pdf, code, spectrum, folder):
    """
    Saves the dataframe into a file
    Inputs: A dataframe, the filename of the file from which the dataframe comes from and its metadata
    Output: None
    
    """
    df, filename,metadata = spectrum.get_dataframe(), spectrum.get_filename(), spectrum.get_metadata()
    #variables
    header = metadata["header"]
    
    #convert dataframe to numpy
    my_numpy_df_data = df.to_numpy()
    
    #get basename
    basename = code + ".csv"

    if not os.path.exists(folder):
        os.mkdir(folder)

    #new_archive_name
    new_archive_name = folder / basename

    #saves info
    with open(new_archive_name, 'wb') as f:
        np.savetxt(new_archive_name, my_numpy_df_data,fmt = "%.6f", delimiter="\t", header=header, comments='', )

# %%
def save_corrected_l1050_spectrum(pdf, code, spectrum, folder):
    """
    Saves the dataframe into a file
    Inputs: A dataframe, the filename of the file from which the dataframe comes from and its metadata
    Output: None
    """
    df, filename,metadata = spectrum.get_dataframe(), spectrum.get_filename(), spectrum.get_metadata()
    #variables
    header = metadata["header"]
    
    #convert dataframe to numpy
    my_numpy_df_data = df.to_numpy()
    
    #get basename
    basename = code + ".csv"

    if not os.path.exists(corrected_path):
        os.mkdir(corrected_path)

    #new_archive_name
    new_archive_name = folder / basename

    #saves info
    with open(new_archive_name, 'wb') as f:
        np.savetxt(new_archive_name, my_numpy_df_data,fmt = "%.6f", delimiter="\t", header=header, comments='', )
    with open(new_archive_name, "r") as f:
        data = f.read()
    with open(new_archive_name, "w") as f:
        f.write(data.replace("#DATA\n","#DATA"))

# %%
def save_corrected_spectrum(pdf, code, spectrum, folder):
    """
    Saves the dataframe into a file
    Inputs: A dataframe, the filename of the file from which the dataframe comes from and its metadata
    Output: None
    
    """
    df, filename,metadata = spectrum.get_dataframe(), spectrum.get_filename(), spectrum.get_metadata()
    #variables
    header = metadata["header"]
    
    #convert dataframe to numpy
    my_numpy_df_data = df.to_numpy()
    
    #Create new folder to save the corrected dataframes
    corrected_path = Path(parent_folder_data_path)
    
    #get basename
    basename = Path(filename).name

    if not os.path.exists(corrected_path):
        os.mkdir(corrected_path)

    #saves file, removes .ASC and removes .SAMPLE
    unnecessary_text = [".Sample", ".Cycle1"]
    temp_text = basename
    
    for text in unnecessary_text:
        #pri*nt(temp_text)
        temp_text = temp_text.replace(text, "")

    #new_archive_name
    new_archive_name = corrected_path / temp_text

    #saves info
    with open(new_archive_name, 'wb') as f:
        np.savetxt(new_archive_name, my_numpy_df_data,fmt = "%.6f", delimiter="\t", header=header, comments='', )
    with open(new_archive_name, "r") as f:
        data = f.read()
    with open(new_archive_name, "w") as f:
        f.write(data.replace("#DATA\n","#DATA"))

# %%
def plot_corrected_spectrum(pdf, code, spectrum, folder, label = None):
    """
    Saves the dataframe into a file
    Inputs: A dataframe, the filename of the file from which the dataframe comes from and its metadata
    Output: None
    
    """
    df, filename,metadata = spectrum.get_dataframe(), spectrum.get_filename(), spectrum.get_metadata()
    equipment = metadata["equipment"]
    polarization = metadata["polarization"]
    genus = metadata["genus"]
    species = metadata["species"]
    species_text = species
    if species == "na":
        species_text = "sp."
    #creates a figure to plot 
    
    
    #plots
    #title = (f'1. Corrected {equipment} spectrum. Code: {code}. {genus} {species_text}. {polarization} pol.')
    
    plt.plot(df["wavelength"], df[metadata["measuring_mode"]], label = label, color= get_contrasting_color())
    #plt.show()
    #save figure

# %%
def get_label_and_color(spectrum, code_file_counter):
    metadata, df = spectrum.get_metadata(), spectrum.get_dataframe()
    filename = spectrum.get_filename()
    basename = Path(filename).name

    #After that we will average the spectra
    #create figure
    color = get_contrasting_color()
    #correct the label to only show the code 
    label_corrected = basename.replace(".csv", "").replace(".ASC", "").replace(".txt", "")

    return label_corrected, color

# %%
def l1050_get_corrected_dataframe_and_info(file, code, collection_list, code_file_counter):
                #create a spectrum object
                spectrum = create_spectrum_from_file(file, code, collection_list)
                label, color = get_label_and_color(spectrum, code_file_counter)
    
                #Fix jump correction
                
                df_corrected = jump_correction(spectrum)
                
                corrected_dict = {"df":df_corrected, "complete_path": file, "metadata": metadata, "code":code}

                return corrected_dict

# %%
def create_spectrum_from_file(file, code, collection_list):
            #pri*nt("Create spectrum from file")
            collection = Specimen_Collection.collection_lookup(code, collection_list)
            #pri*nt(f"{collection=}")
            #pri*nt(f"{file=}")
            spectrum = Spectrum(file, collection)
            
            return spectrum

# %%
def std_CRAIC_df(file_list, code, collection_list):
    #pri*nt(f"Average Craic")
    print(f"Suspicious code {code=}")
    spectra = []
    #create a spectrum for each file
    for file in file_list:
        try:
            
            spectrum = create_spectrum_from_file(file, code, collection_list)
            spectra.append(spectrum)
            #pri*nt(f"{spectra=}")
        except Exception as e: 
            pass
            #pri*nt(e)
    
    #initialize
    std_df = pd.DataFrame([])
    std_df["wavelength"] = []
    std_df["%R"] = []
    #get each dataframe
    dfs = [spectrum.get_dataframe() for spectrum in spectra]
    dfs = [df for df in dfs if not df.empty]
    #print(dfs)
    #average each dataframe
    if dfs:
        grouped_df = pd.concat(dfs).groupby('wavelength')
    std_df = grouped_df.std().reset_index()
    
    #return average dataframe
    return std_df

# %%
def average_CRAIC_df(file_list, code, collection_list):
    #pri*nt(f"Average Craic")
    print(f"Susp. {code}")
    spectra = []
    #create a spectrum for each file
    for file in file_list:
        try:
            spectrum = create_spectrum_from_file(file, code, collection_list)
            spectra.append(spectrum)
            #pri*nt(f"{spectra=}")
        except Exception as e: 
            
            print(e)
    #init average_df
    average_df = pd.DataFrame([])
    average_df["wavelength"] = []
    average_df["%R"] = []
    #get each dataframe
    #print(f"{spectra=}")
    dfs = [spectrum.get_dataframe() for spectrum in spectra]
    dfs = [df for df in dfs if not df.empty]
    #print(f"{dfs=}")
    #average each dataframe
    if dfs:
        grouped_df = pd.concat(dfs).groupby('wavelength')
        average_df = grouped_df.mean().reset_index()
    
    #return average dataframe
    return average_df

# %%
def CRAIC_get_average_polarizations(files_with_code, code):
    #pri*nt(f"{files_with_code=}")
    #pri*nt(f"{code=}")
    #get right and left polarization 
    right_pol= [file for file in files_with_code if "R" in Path(file).name ]
    left_pol= [file for file in files_with_code if "L" in Path(file).name ]
    #no_polarization = [file for file in files_with_code if "T" in Path(file).name]
    no_polarization_average_df = None
    #pri*nt(f"{right_pol=}")
    #pri*nt(f"{left_pol=}")
    #pri*nt(f"{no_polarization=}")
    
    #average each polarization
    #pri*nt("4. right average_CRAIC_df")
    right_average_df = average_CRAIC_df(right_pol, code, collection_list)
    right_average_df["%R"] = right_average_df["%R"] *0.5 #TODO spectral factor for filter correction  
    #pri*nt("4. left average_CRAIC_df")
    left_average_df = average_CRAIC_df(left_pol, code, collection_list)
    left_average_df["%R"] = left_average_df["%R"] *0.5 #TODO spectral factor for filter correction  
    #pri*nt(f"{right_average_df=}")
    #pri*nt(f"{left_average_df=}")
    return right_average_df, left_average_df, no_polarization_average_df

# %%
def CRAIC_get_dataframe_and_info(file, code, collection_list):
                #create a spectrum object
                spectrum = create_spectrum_from_file(file, code, collection_list)
                #no correction needed
                df_corrected = spectrum.get_dataframe()
                metadata = spectrum.get_metadata()
                corrected_dict = {"df":df_corrected, "complete_path": file, "metadata": metadata, "code":code}
    
                return corrected_dict

# %%
def plot_dataframe_before_changes(pdf, file, code, collection_list, code_file_counter):

    #create a spectrum object
    spectrum = create_spectrum_from_file(file, code, collection_list)
    label, color = get_label_and_color(spectrum, code_file_counter)
    
    #get df and metadata
    df = spectrum.get_dataframe()
    metadata = spectrum.get_metadata()
    species = spectrum.get_species()
    genus = spectrum.get_genus()
    polarization = spectrum.get_polarization()
    
    if species == "na":
        species_text = "sp."
    else:
        species_text = species
    
    #pri*nt(f"{species=}")
    #pri*nt(f"{genus=}")
    
    #plots before changes
    plot_wavelength_intensity(metadata, df, kind = None, s=None, alpha = None, color = None, label = label)

# %%
def interpolate_mirror_reflectance(df):
    """real_reflectance = measured_reflectance/100*actual_reflectance"""
    df_copy = df.copy()

    #pri*nt(f"{df_copy =}")
    def actual_reflectance(wavelength):
        actual_reflectance = np.interp(wavelength, correction_df['wavelength'].astype(float), correction_df['reflectance'].astype(float))
        return actual_reflectance

    # Use the interpolation method
    print(f"{df=}")
    df_copy["actual_reflectance"] = df["%R"].apply(actual_reflectance)
    #pri*nt(f"{df_copy["actual_reflectance"] =}")
    df_copy["%R"] = df["%R"] /100* df_copy["actual_reflectance"]
    #pri*nt(f"{df_copy["%R"]=}")
        
    return df_copy.drop("actual_reflectance", axis=1)

# %%
def CRAIC_get_total_average_dataframe(right_average_df, left_average_df):
    
    # Ensure the DataFrames have the same structure
    if right_average_df.shape != left_average_df.shape:
        print(f"{right_average_df=}")
        print(f"{left_average_df=}")
        raise ValueError("DataFrames must have the same shape to compute total averages.")
    
    # Calculate the total average DataFrame
    total_average_df = right_average_df
    total_average_df["%R"] = (right_average_df["%R"] + left_average_df["%R"])
    
    return total_average_df

# %%
def CRAIC_correct_total_average(total_average_df):
    """Corrects the reflectance for each wavelength using interpolate_mirror_reflectance."""
   
    corrected_df = total_average_df.copy()
    corrected_df = interpolate_mirror_reflectance(total_average_df)
                
    return corrected_df

# %%
#Create report
def create_correction_report(filtered_list): #1
    
    #pri*nt(f"1: Create correction report")
    """This function creates a report with the corrected dataframes"""
    file_counter = 0
    genus, species_text, polarization, title = "", "", "", ""
    
    #make a list of all files with code
    files_with_code = []
    for code in codes:
        files_with_code += [file for file in filtered_list if code in file]

    #print(f"{files_with_code=}")
    
    #create a report in pdf with the original files
    
    #create report name
    original_data_file = os.path.join( report_path , f'original_data_{date}.pdf')

    with matplotlib.backends.backend_pdf.PdfPages(original_data_file) as pdf:
        
        for code in codes: 
            #Code by code we will plot all the spectra with the wsame name
            code_file_counter = 1

            #filters each file if the code is in its basename
            files_with_code = [file for file in filtered_list if code in file]
            
            #no results: continue
            if not files_with_code:
                continue
            #print(f"{files_with_code=}")
            
            #separates the files between l1050 files and CRAIC files
            CRAIC_files = [file for file in files_with_code if check_CRAIC_file(file)]
            #print(f"{CRAIC_files=}")
            
            l1050_files = [file for file in files_with_code if check_l1050_file(file)]
            #print(f"{l1050_files=}")

            #no spectroscopy files: continue
            if (not CRAIC_files) and (not l1050_files):
                continue
                
            x_label ="wavelength [nm]"
            y_label = "%R"

            if l1050_files: 
                
                plt.figure(figsize=(10, 4))
                # Create the figure and axes
                fig, ax = plt.subplots()
                draw_rainbow_background()
                
                for file in l1050_files:
                    
                    
                    #create spectrum
                    collection = Specimen_Collection.collection_lookup(code, collection_list)
                    genus,species = Specimen_Collection.genus_species_lookup(code, collection_list)
                    spectrum = Spectrum(file, collection_list,genus,species)
                    metadata = spectrum.get_metadata()
                    
                    
                    code_file_counter += 1
                    file_counter += 1
                    
                    label = str(Path(file).name).replace(".ASC","").replace(".txt","").replace(".csv","")
                    
                    #get df and metadata
                    df = spectrum.get_dataframe()
                    metadata = spectrum.get_metadata()
                    species = spectrum.get_species()
                    genus = spectrum.get_genus()
                    polarization = spectrum.get_polarization()
                    
                    if species == "na":
                        species_text = "sp."
                    else:
                        species_text = species
                        
                    #plots before changes
                    plt.plot(df["wavelength"], df[metadata["measuring_mode"]], color=get_contrasting_color(), label=label)
                    
                    
                    ### end for
    
                    # Labels and title

                
                title = f'1. L1050 raw. Code: {code}. {genus} {species_text}. {polarization} pol.'
                plt.xlabel(x_label)
                plt.ylabel(y_label)
                plt.title(title)
                plt.ylim(0,120)
                plt.legend()
                plt.grid(True)
                #plt.show()
                pdf.savefig()
                plt.close()
            
            ########################################################################################################################
            #CRAIC files 
            
            
            R_files = [file for file in CRAIC_files if "R" in file]
            L_files = [file for file in CRAIC_files if "L" in file]
            O_files = [file for file in CRAIC_files if ("L" not in file) & ("R" not in file)]

            CRAIC_pols = [R_files,L_files,O_files]

            
            
            for i, pol_file in enumerate(CRAIC_pols):
                
                plt.figure(figsize=(10, 4))
                # Create the figure and axes
                fig, ax = plt.subplots()
                draw_rainbow_background()

                pol = ""
                
                for file in pol_file:
                    #create spectrum
                    collection = Specimen_Collection.collection_lookup(code, collection_list)
                    genus,species = Specimen_Collection.genus_species_lookup(code, collection_list)

                    #print(f"{genus=} {species=}")
                    spectrum = Spectrum(file, collection_list,genus,species)
                    metadata = spectrum.get_metadata()
                    pol = metadata["polarization"]
                    label = code +" "+ pol
                    code_file_counter += 1
                    file_counter += 1
        
                    #get df and metadata
                    df = spectrum.get_dataframe()
                    metadata = spectrum.get_metadata()
                    species = spectrum.get_species()
                    genus = spectrum.get_genus()
                    polarization = spectrum.get_polarization()
                    
                    if species == None or species == "na":
                        species_text = "sp"
                    else:
                        species_text = species
                        
                    #plots before changes
                    plt.plot(df["wavelength"], df[metadata["measuring_mode"]], color=get_contrasting_color(), label=label)
                    
                    ### end for
                
                title = f'1. CRAIC raw. Code: {code}. {genus} {species_text}. {pol} pol.'
                plt.xlabel(x_label)
                plt.ylabel(y_label)
                plt.title(title)
                plt.ylim(0,120)
                plt.legend()
                plt.grid(True)
                #plt.show()
                pdf.savefig()
                plt.close()
                
        #end for code in codes: 
            
    ####################################################################################################################################}
    #CORRECTIONS
    
    #create report name
    file_counter = 0
    corrected_data_file = os.path.join( report_path , f'corrected_data_{date}.pdf')
    jump_corrected_dict = []
    average_polarized_dict = []
    #pri*nt(f"1: Create corrected_data_file report")

    with matplotlib.backends.backend_pdf.PdfPages(corrected_data_file) as pdf:
        
        for code in codes:
            
            
            #pri*nt(f"{codes=}")
            #Code by code we will plot all the spectra with the wsame name
            code_file_counter = 1
            #constants
            x_label ="wavelength [nm]"
            y_label = "%R"

            #filters each file if the code is in its basename
            files_with_code = [file for file in filtered_list if code in file]
            #print(f"{files_with_code=}")
            
            #separates the files between l1050 files and CRAIC files
            CRAIC_files = [file for file in files_with_code if check_CRAIC_file(file)]
            #print(f"{CRAIC_files=}")
            
            l1050_files = [file for file in files_with_code if check_l1050_file(file)]
            #print(f"{l1050_files=}")
            
            if l1050_files:
                
                #creates a figure to plot 
                plt.figure(figsize=(10, 4))
                # Create the figure and axes
                fig, ax = plt.subplots()
                draw_rainbow_background()
                #for each l1050 file 
                
                for file in l1050_files:

                    #Get info for each file
                    file = CRAIC_files[0]
                    collection = Specimen_Collection.collection_lookup(code, collection_list)
                    genus,species = Specimen_Collection.genus_species_lookup(code, collection_list)
                    spectrum = Spectrum(file, collection_list,genus,species)
                    metadata = spectrum.get_metadata()

                    #get df and metadata
                    df = spectrum.get_dataframe()
                    metadata = spectrum.get_metadata()
                    species = spectrum.get_species()
                    genus = spectrum.get_genus()
                    polarization = spectrum.get_polarization()
                    
                    #Initialize corrected_dict
                    corrected_dict = {}
                    
                    corrected_dict = l1050_get_corrected_dataframe_and_info(file, code, collection_list, code_file_counter)
    
                    #append files to the jump_corrected_dict to be used later
                    jump_corrected_dict.append(corrected_dict) #declared at the beginning of this method
    
                    #pri*nt(f"{corrected_dict["df_corrected"]=}")
                    #saves the corrected file 
                    basename = corrected_dict["file"]
                    label = str(Path(file).name).replace(".ASC","").replace(".txt","").replace(".csv","")
                    
                    #pri*nt(f"{corrected_dict["df"]}")
                    save_corrected_df(folder=corrected_files, basename = Path(file).name, metadata=corrected_dict["metadata"], dataframe=corrected_dict["df"])
                    save_corrected_plot(folder = corrected_files, basename = Path(file).name,metadata = dict["metadata"], dataframe=corrected_dict["df"], label = label )
                    
                    ### end for
                plt.title(f'1. L1050. Jump Correction. {code}')
                plt.xlabel(x_label)
                plt.ylabel(y_label)
                plt.ylim(0,120)
                plt.legend()
                plt.grid(True)
                #plt.show()
                pdf.savefig()
                plt.close()

            
            #Now for CRAIC files, these are separated between R, L and O polarization
            #and these are not corrected for jumps, only pri*nted
            code_file_counter = 1
            
            #creates a figure to plot
            if CRAIC_files:
                code_file_counter += 1
                
                #Get info for each file
                file = CRAIC_files[0]
                collection = Specimen_Collection.collection_lookup(code, collection_list)
                genus,species = Specimen_Collection.genus_species_lookup(code, collection_list)
                spectrum = Spectrum(file, collection_list,genus,species)
                metadata = spectrum.get_metadata()

                #check polarizations
                right_pol= [file for file in files_with_code if "R" in Path(file).name ]
                left_pol= [file for file in files_with_code if "L" in Path(file).name ]
                no_polarization = [file for file in files_with_code if ("O" in Path(file).name or "T" in Path(file).name)]

                if (not right_pol) or (not left_pol):
                    continue
                #pri*nt("2. CRAIC_get_average_polarizations")
                
                right_average_df, left_average_df, no_polarization_average_df = CRAIC_get_average_polarizations(CRAIC_files, code)
                #print(f"{right_average_df=}")
                #print(f"{left_average_df=}")
                right_pol_path = corrected_files_path / "R"
                left_pol_path = corrected_files_path / "L"

                plt.figure(figsize=(10, 4))
                # Create the figure and axes
                
                draw_rainbow_background()

                #set polarization to R and save
                metadata["polarization"] = "R"
                basename = code+ "_R.csv"
                
                save_corrected_df(folder = right_pol_path, basename = basename ,metadata = metadata,dataframe = right_average_df )
                
                label = code + "_R"
                
                save_corrected_plot(folder = right_pol_path, basename = basename,metadata = metadata,dataframe = right_average_df, label = label )
                

                #set polarization to L and save
                metadata["polarization"] = "L"
                basename = code+ "_L.csv"
                save_corrected_df(folder = left_pol_path, basename = basename ,metadata = metadata,dataframe = left_average_df )

                label = (code + "_L")
                save_corrected_plot(folder = left_pol_path, basename = basename ,metadata = metadata,dataframe = left_average_df, label = label )

                
                #get average polarizations
                    
                    
                #get total average_df
                #pri*nt("2. CRAIC_get_total_average_dataframe")
                total_average_df = pd.DataFrame([])
                try:
                    total_average_df = CRAIC_get_total_average_dataframe(right_average_df, left_average_df)
                except Exception as e:
                    print(e)
                #get corrected total average
                #pri*nt("2. CRAIC_correct_total_average")
                
                corrected_total_average_df = CRAIC_correct_total_average(total_average_df)

                #p*rint(f"{corrected_total_average_df=}")
                

                basename = code + ".csv"

                
    
                #saves the corrected file save_corrected_df(folder, basename, metadata, dataframe)
                #pri*nt("2. save_corrected_df")
                #set polarization to O and save
                metadata["polarization"] = "T"
                basename = code +".csv"
                save_corrected_df(folder = corrected_files_path, basename = basename,metadata = metadata,dataframe = corrected_total_average_df )
                label = (code) + "_O"
                save_corrected_plot(folder = corrected_files_path, basename = basename,metadata = metadata,dataframe = corrected_total_average_df, label = label )
                
                plt.title(f'1. CRAIC. R, L and total. Code {code}. {genus} {species}')
                plt.xlabel(x_label)
                plt.ylabel(y_label)
                plt.ylim(0,120)
                plt.legend()
                plt.grid(True)
                #plt.show()
                pdf.savefig()
                plt.close()
                ### end for
                
           
create_correction_report(non_empty_files)
# Out:
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037298R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037298R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037298R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037298L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037298L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037298L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\1037298-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\1037298-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\1037298-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037299R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037299R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037299R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037299L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037299L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037299L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\1037299-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\1037299-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\1037299-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037308R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037308R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037308R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037308L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037308L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037308L3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\esteb\cicima\escarabajos\libraries\spectraltools.py:104: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:118: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 4))
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037312R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037312L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037312L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1037312L3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1054219R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1054219R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1054219R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1054219L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1054219L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1054219L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\1054219-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\1054219-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\1054219-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1309367R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1309367R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1309367R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1309367L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1309367L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1309367L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\159438R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\159438R2.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\159438R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1717606R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1717606R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1717606R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1717606L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1717606L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1717606L3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736458R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736458R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736458R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736458L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736458L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736458L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736459R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736459R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736459R3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736459L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736459L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\1736459L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\209836R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\209836R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\209836R3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\209836L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\209836L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\209836L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2181994R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2181994R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2181994R3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2181994L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2181994L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2181994L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195354R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195354R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195354R3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195354L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195354L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195354L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195355R1.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195355R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195355R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195355L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195355L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195355L3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195357R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195357R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195357R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195357L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195357L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195357L3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195358R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195358R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195358R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195358L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195358L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2195358L3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2234738R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2234738R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2234738R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2234738L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2234738L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2234738L3.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2248544R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2248544R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2248544R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2248544L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2248544L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2248544L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2248544-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2248544-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2248544-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249504R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249504R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249504R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249504L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249504L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249504L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505R4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505R5.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505L4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2249505L5.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2249505-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2249505-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2249505-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2253302R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2253302R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2253302R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2253302L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2253302L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2253302L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2253302-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2253302-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2253302-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2361339R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2361339R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2361339L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2361339L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2361339-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2361339-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2361339-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2375565R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2375565R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2375565R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2375565R4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2375565L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2375565L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2375565L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2375565L4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2375565-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2375565-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2375565-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856R4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856R5.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856L4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376856L5.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2376856-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2376856-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2376856-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376857R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376857R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376857R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376857R4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376857L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376857L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376857L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2376857L4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2376857-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2376857-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2376857-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388550R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388550R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388550R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388550R4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388550L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388550L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388550L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388550L4.csv'
# format_type='craic_filename_regex_1'
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\639115970.py:160: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388554R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388554R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388554R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388554L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388554L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2388554L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2388554-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2388554-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2388554-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422833R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422833R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422833R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422833L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422833L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422833L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2422833-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2422833-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2422833-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422834R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422834R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422834R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422834L1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422834L2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2422834L3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2422834-1.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2422834-2.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Medidas1\uf0270Abril2019\\C_cupreomarginata\\2422834-3.csv'
# format_type='l1050_filename_regex'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2452030R1.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2452030R2.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2452030R3.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2452030R4.csv'
# format_type='craic_filename_regex_1'
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\2452030L1.csv'
# format_type='craic_filename_regex_1'
# ...
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# df=      wavelength         %R
# 0     420.190645  14.210006
# 1     420.624620  14.134645
# 2     421.058582  14.048093
# 3     421.492531  13.991272
# 4     421.926468  13.954956
# ...          ...        ...
# 1254  948.018347  37.854821
# 1255  948.421179  37.633663
# 1256  948.823974  37.435797
# 1257  949.226732  37.235232
# 1258  949.629453  37.034489
#
# [1259 rows x 2 columns]
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\668621L1.csv'
# format_type='craic_filename_regex_1'
# Susp. 668621
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\668621R1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\668621R2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\668621R3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# Susp. 668621
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\668621L1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\668621L2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\668621L3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# df=      wavelength         %R
# 0     420.190645  24.725462
# 1     420.624620  24.653667
# 2     421.058582  24.582920
# 3     421.492531  24.543198
# 4     421.926468  24.525929
# ...          ...        ...
# 1254  948.018347  22.508326
# 1255  948.421179  22.406881
# 1256  948.823974  22.312357
# 1257  949.226732  22.222781
# 1258  949.629453  22.138855
#
# [1259 rows x 2 columns]
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714869L1.csv'
# format_type='craic_filename_regex_1'
# Susp. 714869
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714869R1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714869R2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714869R3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# Susp. 714869
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714869L1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714869L2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714869L3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# df=      wavelength         %R
# 0     420.190645  23.442143
# 1     420.624620  23.394085
# 2     421.058582  23.359147
# 3     421.492531  23.338944
# 4     421.926468  23.317551
# ...          ...        ...
# 1254  948.018347  46.729954
# 1255  948.421179  46.646533
# 1256  948.823974  46.574493
# 1257  949.226732  46.463815
# 1258  949.629453  46.383936
#
# [1259 rows x 2 columns]
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714947L1.csv'
# format_type='craic_filename_regex_1'
# Susp. 714947
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714947R1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714947R2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714947R3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# Susp. 714947
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714947L1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714947L2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\714947L3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# df=      wavelength         %R
# 0     420.190645  20.852261
# 1     420.624620  20.843659
# 2     421.058582  20.820261
# 3     421.492531  20.832017
# 4     421.926468  20.831742
# ...          ...        ...
# 1254  948.018347  35.781289
# 1255  948.421179  35.541354
# 1256  948.823974  35.315455
# 1257  949.226732  35.078318
# 1258  949.629453  34.870523
#
# [1259 rows x 2 columns]
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\776563L1.csv'
# format_type='craic_filename_regex_1'
# Susp. 776563
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\776563R1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\776563R2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\776563R3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# Susp. 776563
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\776563L1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\776563L2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\776563L3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# df=      wavelength         %R
# 0     420.190645  14.529390
# 1     420.624620  14.437732
# 2     421.058582  14.352898
# 3     421.492531  14.294636
# 4     421.926468  14.237953
# ...          ...        ...
# 1254  948.018347  42.893492
# 1255  948.421179  42.814753
# 1256  948.823974  42.752682
# 1257  949.226732  42.660089
# 1258  949.629453  42.582354
#
# [1259 rows x 2 columns]
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\856696L1.csv'
# format_type='craic_filename_regex_1'
# Susp. 856696
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\856696R1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\856696R2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\856696R3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# Susp. 856696
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\856696L1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\856696L2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\856696L3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# df=      wavelength         %R
# 0     420.190645  26.839012
# 1     420.624620  26.707812
# 2     421.058582  26.576539
# 3     421.492531  26.491496
# 4     421.926468  26.415903
# ...          ...        ...
# 1254  948.018347  41.032188
# 1255  948.421179  40.876751
# 1256  948.823974  40.747215
# 1257  949.226732  40.613366
# 1258  949.629453  40.471146
#
# [1259 rows x 2 columns]
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\987517L1.csv'
# format_type='craic_filename_regex_1'
# Susp. 987517
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\987517R1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\987517R2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\987517R3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# Susp. 987517
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\987517L1.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\987517L2.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# string_line='C:\\Users\\esteb\\cicima\\escarabajos\\test\\data\\test_step_jump_correction\\files\\Mediciones Chrysina\\Espectros 2018\\987517L3.csv'
# format_type='craic_filename_regex_1'
# No genus data for None in collection INBIO
# No species data for None in collection INBIO
# Update specimen in the corresponding collection, please
# df=      wavelength         %R
# 0     420.190645  23.352237
# 1     420.624620  23.246611
# 2     421.058582  23.145108
# 3     421.492531  23.075063
# 4     421.926468  22.990946
# ...          ...        ...
# 1254  948.018347  39.152019
# 1255  948.421179  39.075575
# 1256  948.823974  38.992316
# 1257  949.226732  38.889071
# 1258  949.629453  38.797354
#
# [1259 rows x 2 columns]

# %%
var_dataframes = None
def average_l1050_files(file_list, code_set, directory, pdf):

    #parent directory and save_directory
    jump_corrected_path = os.path.join( directory , "jump_corrected_files")
    save_directory = os.path.dirname(jump_corrected_path)
    
    #p*rint(f"{save_directory=}")
    file_counter = 0

    #Look for every available code in the folder
    for code in code_set:
        #pr*int(f"{code=}") 
        
        dataframes = []
        files_with_code =[file for file in file_list if code in Path(file).name] #gets each file that starts with the code provided
        #pri*nt(files_with_code)
        metadata, df = None, None
        
        # Read each file, create dataframes, and plot them
        for file_path in file_list:
            #pri*nt(f"{file_path=}")
            #create spectrum object
            collection = Specimen_Collection.collection_lookup(code, collection_list)
            spectrum = Spectrum(file_path, collection_list)
            
            #get metadata and dataframe
            #pri*nt("Reading file...")
            #pri*nt("Getting metadata and dataframe...")
            metadata, df = spectrum.get_metadata(), spectrum.get_dataframe()

            #metadata info
            measuring_mode = metadata["measuring_mode"]
            sample_name = metadata["code"] 

            # Read the file into a pandas DataFrame
            #convert columns to float
            #pri*nt("Converting columns to float...")
            df['wavelength'] = df['wavelength'].astype(float)
            df[measuring_mode] = df[measuring_mode].astype(float)
            
            #pri*nt("Dropping index...")
            try:
                df = df.drop("index", axis = 1)
            except Exception as e:
                #pri*nt (e)
                pass
            #pri*nt("pri*nting head...")
            
            #pri*nt(df.head())
            # Append the dataframe to the list if not empty
            if not df.empty and not None and len(df) != 0:
                dataframes.append(df) 
            
        # Calculate the average of all dataframes ignore empty ones
        # average l1050 files and polarization_sum CRAIC files
        #pri*nt("elements")
        
        #pri*nt(dataframes)
        #pri*nt(f"{len(dataframes)=}")

        #If there are no dataframes, continue
        if len(dataframes) == 0:
            continue
        #If there is only one 
        elif len(dataframes) == 1:
            average_df = dataframes[0]
            std_dev_df = pd.DataFrame([])
            std_dev_df["wavelength"] = []
            std_dev_df["%R"] =[]
        #If there are many
        else:
            average_df = pd.concat(dataframes).groupby('wavelength').mean().reset_index()
            std_dev_df = pd.concat(dataframes).groupby('wavelength').std().reset_index()

        try: 
            #pri*nt(f"{average_df=}")
            
            #average plot
            
            plot_wavelength_intensity(metadata = metadata, dataframe = average_df,kind='scatter', s=markersize, label = sample_name + " avg" )
            #save figures
            plt.title(f"Average. Code {code}")
            plt.ylim(0,y.max()*1.1)
            pdf.savefig()
            #close plot
            plt.close()
            
            # #standard deviation plot
            # std_plot = std_dev_df.plot(x='wavelength', y=measuring_mode, color = "r", kind='scatter', s=markersize, title = sample_name + " std dev", figsize = (10,4), grid=True)
            # #save figures
            # pdf.savefig()
            # #close plot
            # plt.close()
        except Exception as e:
            pass
            #pri*nt(e)
            
        #SAVE FILE
        #Convert to numpy
        average_np = average_df.to_numpy()
        std_dev_np = std_dev_df.to_numpy()
        
        #Create new folder
      
        avg_new_path = os.path.join(save_directory , "average")
        std_dev_new_path = os.path.join(save_directory , "std_dev") 

        
        if not os.path.exists(avg_new_path):
            os.mkdir(avg_new_path)
        if not os.path.exists(std_dev_new_path):
            os.mkdir(std_dev_new_path)

        #creates new filename
        #pri*nt(f"sample name: {sample_name}")

        new_avg_archive_name = os.path.join(avg_new_path, sample_name+'.txt')
        new_std_dev_archive_name = os.path.join( std_dev_new_path , sample_name+'.txt')

        #pri*nt(new_avg_archive_name)
        #saves files
        np.savetxt(new_avg_archive_name, average_np,fmt = "%.6f", delimiter="\t", header=metadata["header"], comments='')
        np.savetxt(new_std_dev_archive_name, std_dev_np,fmt = "%.6f", delimiter="\t", header=metadata["header"], comments='')
        #pri*nt("fin de la iteracion")

        def delete_blank_row(archive_name):
            with open(archive_name, "r") as f:
                data = f.read()
            with open(archive_name, "w") as f:
                f.write(data.replace("#DATA\n","#DATA"))

        delete_blank_row(new_avg_archive_name)
        delete_blank_row(new_std_dev_archive_name)
                         
        file_counter = file_counter +1
        
    #pri*nt(f"{file_counter} averages were calculated")
    #pri*nt(f"Report file is located in {save_directory}")

# %%
var_dataframes = None
def std_l1050_files(file_list, code_set, directory, pdf):

    #parent directory and save_directory
    jump_corrected_path = os.path.join( directory , "jump_corrected_files")
    save_directory = os.path.dirname(jump_corrected_path)
    
    #p*rint(f"{save_directory=}")
    file_counter = 0

    #Look for every available code in the folder
    for code in code_set:
        #pr*int(f"{code=}") 
        
        dataframes = []
        files_with_code =[file for file in file_list if code in Path(file).name] #gets each file that starts with the code provided
        #pri*nt(files_with_code)
        metadata, df = None, None
        
        # Read each file, create dataframes, and plot them
        for file_path in file_list:
            #pri*nt(f"{file_path=}")
            #create spectrum object
            collection = Specimen_Collection.collection_lookup(code, collection_list)
            spectrum = Spectrum(file_path, collection_list)
            
            #get metadata and dataframe
            #pri*nt("Reading file...")
            #pri*nt("Getting metadata and dataframe...")
            metadata, df = spectrum.get_metadata(), spectrum.get_dataframe()

            #metadata info
            measuring_mode = metadata["measuring_mode"]
            sample_name = metadata["code"] 

            # Read the file into a pandas DataFrame
            #convert columns to float
            #pri*nt("Converting columns to float...")
            df['wavelength'] = df['wavelength'].astype(float)
            df[measuring_mode] = df[measuring_mode].astype(float)
            
            #pri*nt("Dropping index...")
            try:
                df = df.drop("index", axis = 1)
            except Exception as e:
                #pri*nt (e)
                pass
            #pri*nt("pri*nting head...")
            
            #pri*nt(df.head())
            # Append the dataframe to the list if not empty
            if not df.empty and not None and len(df) != 0:
                dataframes.append(df) 
            
        # Calculate the average of all dataframes ignore empty ones
        # average l1050 files and polarization_sum CRAIC files
        #pri*nt("elements")
        
        #pri*nt(dataframes)
        #pri*nt(f"{len(dataframes)=}")

        #If there are no dataframes, continue
        if len(dataframes) == 0:
            continue
        #If there is only one 
        elif len(dataframes) == 1:
            average_df = dataframes[0]
            std_dev_df = pd.DataFrame([])
        #If there are many
        else:
            average_df = pd.concat(dataframes).groupby('wavelength').mean().reset_index()
            std_dev_df = pd.concat(dataframes).groupby('wavelength').std().reset_index()

        try: 
            #pri*nt(f"{average_df=}")
            
            #average plot
         
            
            #standard deviation plot
            std_plot = std_dev_df.plot(x='wavelength', y=measuring_mode, color = "r", kind='scatter', s=markersize, title = sample_name + " std dev", figsize = (10,4), grid=True)
            #save figures
            pdf.savefig()
            #close plot
            plt.close()
        except Exception as e:
            pass
            #pri*nt(e)
            
        #SAVE FILE
        #Convert to numpy
        average_np = average_df.to_numpy()
        std_dev_np = std_dev_df.to_numpy()
        
        #Create new folder
      
        avg_new_path = os.path.join(save_directory , "average")
        std_dev_new_path = os.path.join(save_directory , "std_dev") 

        
        if not os.path.exists(avg_new_path):
            os.mkdir(avg_new_path)
        if not os.path.exists(std_dev_new_path):
            os.mkdir(std_dev_new_path)

        #creates new filename
        #pri*nt(f"sample name: {sample_name}")

        new_avg_archive_name = os.path.join(avg_new_path, sample_name+'.txt')
        new_std_dev_archive_name = os.path.join( std_dev_new_path , sample_name+'.txt')

        #pri*nt(new_avg_archive_name)
        #saves files
        np.savetxt(new_avg_archive_name, average_np,fmt = "%.6f", delimiter="\t", header=metadata["header"], comments='')
        np.savetxt(new_std_dev_archive_name, std_dev_np,fmt = "%.6f", delimiter="\t", header=metadata["header"], comments='')
        #pri*nt("fin de la iteracion")

        def delete_blank_row(archive_name):
            with open(archive_name, "r") as f:
                data = f.read()
            with open(archive_name, "w") as f:
                f.write(data.replace("#DATA\n","#DATA"))

        delete_blank_row(new_avg_archive_name)
        delete_blank_row(new_std_dev_archive_name)
                         
        file_counter = file_counter +1
        
    #pri*nt(f"{file_counter} averages were calculated")
    #pri*nt(f"Report file is located in {save_directory}")

# %%
def average_CRAIC_files(file_list, code, directory, pdf):

    for file in file_list:

        #pri*nt("3. CRAIC_get_average_polarizations")
        right_average_df, left_average_df, no_pol_average_df = CRAIC_get_average_polarizations(files_with_code= file_list, code = code)
        #pri*nt(f"{right_average_df=}")
        #pri*nt(f"{left_average_df=}")
        total_average_df = pd.DataFrame([])
        if right_average_df.empty or not left_average_df.empty:
            raise Exception("These dfs can't be empty")
        #return average dataframe
        if not right_average_df.empty and not left_average_df.empty:
            total_average_df = CRAIC_get_total_average_dataframe(right_average_df, left_average_df)
        if total_average_df.empty:
            total_average_df = no_pol_average_df
        #pri*nt(f"{total_average_df=}")
        #correct it 
        corrected_df = CRAIC_correct_total_average(total_average_df)
        #pri*nt(f"{corrected_df=}")
        #create spectrum with that df

        return corrected_df

# %%
def std_CRAIC_df(file_list, code, collection_list):
    #pri*nt(f"Average Craic")
    spectra = []
    #create a spectrum for each file
    for file in file_list:
        try:
            
            spectrum = create_spectrum_from_file(file, code, collection_list)
            spectra.append(spectrum)
            #pri*nt(f"{spectra=}")
        except Exception as e: 
            pass
            #pri*nt(e)
            
    #get each dataframe
    dfs = [spectrum.get_dataframe() for spectrum in spectra]
    dfs = [df for df in dfs if not df.empty]
    #print(dfs)
    #average each dataframe
    grouped_df = pd.concat(dfs).groupby('wavelength')
    std_df = grouped_df.std().reset_index()
    
    #return average dataframe
    return std_df

# %%
def CRAIC_get_std_polarizations(files_with_code= file_list, code = code):
    #pri*nt(f"{files_with_code=}")
    #pri*nt(f"{code=}")
    #get right and left polarization 
    right_pol= [file for file in files_with_code if "R" in Path(file).name ]
    left_pol= [file for file in files_with_code if "L" in Path(file).name ]
    #no_polarization = [file for file in files_with_code if "T" in Path(file).name]
    no_polarization_std_df = None
    #pri*nt(f"{right_pol=}")
    #pri*nt(f"{left_pol=}")
    #pri*nt(f"{no_polarization=}")
    #average each polarization
    #pri*nt("4. right average_CRAIC_df")
    right_std_df = std_CRAIC_df(right_pol, code, collection_list)
    right_std_df["%R"] = right_std_df["%R"] *0.5 #TODO spectral factor for filter correction  
    #pri*nt("4. left average_CRAIC_df")
    left_std_df = std_CRAIC_df(left_pol, code, collection_list)
    left_std_df["%R"] = left_std_df["%R"] *0.5 #TODO spectral factor for filter correction  
    #pri*nt(f"{right_average_df=}")
    #pri*nt(f"{left_average_df=}")
    return right_std_df, left_std_df, no_polarization_std_df

# %%
def CRAIC_get_total_std_dataframe(right_std_df, left_std_df):
    
    # Ensure the DataFrames have the same structure
    if right_std_df.shape != left_std_df.shape:
        raise ValueError("DataFrames must have the same shape to compute total averages.")
    
    # Calculate the total average DataFrame
    total_std_df = right_std_df
    #sigma_Z = np.sqrt(sigma_X**2 + sigma_Y**2)
    total_std_df["%R"] = (right_std_df["%R"]*right_std_df["%R"] + left_std_df["%R"]*left_std_df["%R"])**(1/2)
    
    return total_std_df

# %%
def std_CRAIC_files(file_list, code, directory, pdf):

    for file in file_list:

        #pri*nt("3. CRAIC_get_average_polarizations")
        right_average_df, left_average_df, no_pol_average_df = CRAIC_get_average_polarizations(files_with_code= file_list, code = code)
        right_std_df, left_std_df, no_pol_std_df = CRAIC_get_std_polarizations(files_with_code= file_list, code = code)
        #pri*nt(f"{right_average_df=}")
        #pri*nt(f"{left_average_df=}")
      
        #return average dataframe
        total_std_df = CRAIC_get_total_std_dataframe(right_std_df, left_std_df)
        
        #pri*nt(f"{total_average_df=}")
        #correct it 
        #pri*nt(f"{corrected_df=}")
        #create spectrum with that df

        return total_std_df

# %%
# From this list we will make a set of codes.
#pri*nt(filenames)
codes_2 = codes
#pri*nt(f"codes {codes}")

# %%
### Calculate the average for each spectrum if it has the same name
avg_std_report_file = report_path.parent/ Path(parent_folder_data_path).name / f"average_report_{date}.pdf"
#pri*nt(avg_std_report_file)

with matplotlib.backends.backend_pdf.PdfPages(avg_std_report_file) as pdf:
    
    for code in codes_2:

        files_with_code = [file for file in non_empty_files if code in file]
        
        #separates the files between l1050 files and CRAIC files
        
        CRAIC_files = [file for file in files_with_code if check_CRAIC_file(file)]
        l1050_files = [file for file in files_with_code if check_l1050_file(file)]

        type_of_file = [CRAIC_files, l1050_files]

        for elem, type_of_file in enumerate(l1050_files): 
            if (len(CRAIC_files) >= 1) and (elem ==0):
                file_path = CRAIC_files[0]
                #print(file)
                collection = Specimen_Collection.collection_lookup(code, collection_list)
                genus,species = Specimen_Collection.genus_species_lookup(code, collection_list)
                spectrum = Spectrum(file_path, collection_list,genus,species)
                metadata = spectrum.get_metadata()
                try:
                    df = average_CRAIC_files(file_list=CRAIC_files, code= code, directory= avg_std_report_file, pdf=pdf)
                except Exception as e:
                    print(e)
                    continue
                #pri*nt(f"{df=}")
                spectrum.set_dataframe(df)
                
                save_corrected_CRAIC_spectrum(pdf= pdf, code = code, spectrum = spectrum, folder = Path(parent_folder_data_path).parent)
                
                plt.figure(figsize=(10, 4))
                draw_rainbow_background()
                plot_corrected_spectrum(pdf= pdf, code = code, spectrum = spectrum, folder = Path(parent_folder_data_path).parent)
                
                plt.ylim(0,120)
                plt.xlabel("wavelength [nm]")
                plt.ylabel(f"{metadata['measuring_mode']}")
                plt.title(f"CRAIC. Std Dev. {genus} {species}. Code: {code}.  ")
                plt.legend()
                plt.grid(True)
                #plt.show()
                pdf.savefig()
                plt.close()
                
            elif len(l1050_files) >= 1:
                file_path = l1050_files[0]
                genus,species = Specimen_Collection.genus_species_lookup(code, collection_list)
                spectrum2 = Spectrum(file_path, collection_list,genus,species)
                metadata = spectrum2.get_metadata()
                df = std_l1050_files(file_list=l1050_files, code_set= code_set, directory= avg_std_report_file, pdf=pdf)
                #pri*nt(df)
                spectrum2.set_dataframe(df)
                save_corrected_l1050_spectrum(pdf= pdf, code = code, spectrum = spectrum2, folder = Path(parent_folder_data_path).parent)
                
                plt.figure(figsize=(10, 4))
                draw_rainbow_background()
                
                plot_corrected_spectrum(pdf= pdf, code = code, spectrum = spectrum2, folder = Path(parent_folder_data_path).parent)
                plt.title(f"L1050. Std Dev. {genus} {species}. Code: {code}.")
                plt.xlabel("wavelength [nm]")
                plt.ylabel(f"{metadata['measuring_mode']}")
                plt.ylim(0,120)
                plt.legend()
                plt.grid(True)
                #plt.show()
                pdf.savefig()
                plt.close()
# Out:
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\552679818.py:5: MatplotlibDeprecationWarning: Keeping empty pdf files is deprecated since 3.8 and support will be removed in 3.10.
#   with matplotlib.backends.backend_pdf.PdfPages(avg_std_report_file) as pdf:

# %%
### Calculate the average for each spectrum if it has the same name
avg_std_report_file = report_path.parent/ Path(parent_folder_data_path).name / f"standard_deviation_report_{date}.pdf"
#pri*nt(avg_std_report_file)

with matplotlib.backends.backend_pdf.PdfPages(avg_std_report_file) as pdf:
    
    for code in codes_2:

        files_with_code = [file for file in non_empty_files if code in file]
        
        #separates the files between l1050 files and CRAIC files
        
        CRAIC_files = [file for file in files_with_code if check_CRAIC_file(file)]
        l1050_files = [file for file in files_with_code if check_l1050_file(file)]
        type_of_file = [CRAIC_files, l1050_files]

        for elem, type_of_file in enumerate(l1050_files): 
            if (len(CRAIC_files) >= 1) and (elem ==0):
                file_path = CRAIC_files[0]
                collection = Specimen_Collection.collection_lookup(code, collection_list)
                genus,species = Specimen_Collection.genus_species_lookup(code, collection_list)
                spectrum = Spectrum(file_path, collection_list,genus,species)
                metadata = spectrum.get_metadata()
                df = std_CRAIC_files(file_list=CRAIC_files, code= code, directory= avg_std_report_file, pdf=pdf)
                #pri*nt(f"{df=}")
                spectrum.set_dataframe(df)
                
                save_corrected_CRAIC_spectrum(pdf= pdf, code = code, spectrum = spectrum, folder = Path(parent_folder_data_path).parent)
                
                plt.figure(figsize=(10, 4))
                draw_rainbow_background()
                plot_corrected_spectrum(pdf= pdf, code = code, spectrum = spectrum, folder = Path(parent_folder_data_path).parent)
                
                plt.ylim(0,120)
                plt.xlabel("wavelength [nm]")
                plt.ylabel(f"{metadata['measuring_mode']}")
                plt.title(f"CRAIC. Average. {genus} {species}. Code: {code}.  ")
                plt.legend()
                plt.grid(True)
                #plt.show()
                pdf.savefig()
                plt.close()
                
            elif len(l1050_files) >= 1:
                file_path = l1050_files[0]
                genus,species = Specimen_Collection.genus_species_lookup(code, collection_list)
                spectrum2 = Spectrum(file_path, collection_list,genus,species)
                metadata = spectrum2.get_metadata()
                df = std_l1050_files(file_list=l1050_files, code_set= code_set, directory= avg_std_report_file, pdf=pdf)
                #pri*nt(df)
                spectrum2.set_dataframe(df)
                save_corrected_l1050_spectrum(pdf= pdf, code = code, spectrum = spectrum2, folder = Path(parent_folder_data_path).parent)
                
                plt.figure(figsize=(10, 4))
                draw_rainbow_background()
                
                plot_corrected_spectrum(pdf= pdf, code = code, spectrum = spectrum2, folder = Path(parent_folder_data_path).parent)
                plt.title(f"L1050. Average. {genus} {species}. Code: {code}.")
                plt.xlabel("wavelength [nm]")
                plt.ylabel(f"{metadata['measuring_mode']}")
                plt.ylim(0,120)
                plt.legend()
                plt.grid(True)
                #plt.show()
                pdf.savefig()
                plt.close()
# Out:
# C:\Users\esteb\AppData\Local\Temp\ipykernel_44292\3702505704.py:5: MatplotlibDeprecationWarning: Keeping empty pdf files is deprecated since 3.8 and support will be removed in 3.10.
#   with matplotlib.backends.backend_pdf.PdfPages(avg_std_report_file) as pdf:
